# %%
import requests
import json

url = "https://raw.githubusercontent.com/goncalogteixeira/onlyActionFiles/master/parsedRaw.json"

r = requests.get(url)
houses = json.loads(r.text)
houses
#print( "Number of houses read:" , len(houses) )

# short resume of houses
# Out:
# [{'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '927',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/1_e1f3f9c5-14ec-412f-bc07-f432f1cb7b13.jpg',
#   'link': 2027635,
#   'location': 'Portugal, Setubal, Montijo, Sarilhos Grandes, Lancada',
#   'nbaths': '1',
#   'nrooms': '2',
#   'price': '175 000 EUR',
#   'ref': '0651-03040',
#   'state_prop': 'Bom',
#   'state_sale': 'Venda',
#   'type_prop': 'Moradia',
#   'usefull_area': '140'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '683',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/-103-_47b8c61f-908c-4746-beda-eca290a2a7ac.jpg',
#   'link': 2029719,
#   'location': 'Portugal, Coimbra, Lousa, Lousa e Vilarinho, Vila da Lousa (Vilarinho)',
#   'nbaths': '1',
#   'nrooms': '3',
#   'price': '65 000 EUR',
#   'ref': 'C0289-00613',
#   'state_prop': 'Bom',
#   'state_sale': 'Venda',
#   'type_prop': 'Moradia',
#   'usefull_area': '124'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '2 000',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/5_d6d403e3-2c17-4048-a02b-b7934f709a24.jpg',
#   'link': 2030232,
#   'location': 'Portugal, Vila Real, Chaves, Santa Cruz/Trindade e Sanjurge',
#   'nbaths': '5',
#   'nrooms': '4',
#   'price': '400 000 EUR',
#   'ref': 'C0395-00152',
#   'state_prop': 'Bom',
#   'state_sale': 'Venda',
#   'type_prop': 'Moradia',
#   'usefull_area': '330'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '355',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/img-4484_4463a4bc-c0aa-4969-91a3-54c44779d7f7.jpg',
#   'link': 2016095,
#   'location': 'Portugal, Setubal, Montijo, Montijo e Afonsoeiro, Bairro do Saldanha',
#   'nbaths': '4',
#   'nrooms': '4',
#   'price': '347 000 EUR',
#   'ref': 'C0364-00340',
#   'state_prop': 'Bom',
#   'state_sale': 'Venda',
#   'type_prop': 'Moradia',
#   'usefull_area': '270'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '1 318',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/-144-_ad63aebd-1a1c-492c-b5eb-cf70653fd374.jpg',
#   'link': 2023259,
#   'location': 'Portugal, Coimbra, Arganil, Pombeiro da Beira',
#   'nbaths': '1',
#   'nrooms': '4',
#   'price': '66 500 EUR',
#   'ref': 'C0289-00612',
#   'state_prop': 'Bom',
#   'state_sale': 'Venda',
#   'type_prop': 'Moradia',
#   'usefull_area': '168'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '747',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/img-5922_f89bf067-5704-4683-a074-aec9c1e4ab54.jpg',
#   'link': 2024639,
#   'location': 'Portugal, Lisboa, Sintra, Queluz e Belas, Idanha',
#   'nbaths': '4',
#   'nrooms': '6',
#   'price': '599 000 EUR',
#   'ref': 'C0246-01924',
#   'state_prop': 'Bom',
#   'state_sale': 'Venda',
#   'type_prop': 'Moradia',
#   'usefull_area': '260'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '243',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/image00010_48e678fd-d97a-4107-851c-6b381c10797d.jpg',
#   'link': 2025141,
#   'location': 'Portugal, Setubal, Almada, Laranjeiro e Feijo, Quinta da Alembranca',
#   'nbaths': '3',
#   'nrooms': '5',
#   'price': '300 000 EUR',
#   'ref': '0651-03037',
#   'state_prop': 'Bom',
#   'state_sale': 'Venda',
#   'type_prop': 'Moradia',
#   'usefull_area': '192'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '6 410',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/img-6898_d9fe785d-21bf-4e94-a950-68db8fcbb84a.JPG',
#   'link': 2027082,
#   'location': 'Portugal, Viseu, Viseu, Couto de Baixo e Couto de Cima',
#   'nbaths': '3',
#   'nrooms': '3',
#   'price': '295 000 EUR',
#   'ref': 'C0203-01554',
#   'state_prop': 'Bom',
#   'state_sale': 'Venda',
#   'type_prop': 'Moradia',
#   'usefull_area': '175'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '678',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/img-8114_ce4168df-0b14-4243-9005-da3ba623b3df.JPG',
#   'link': 2027106,
#   'location': 'Portugal, Santarem, Coruche, Coruche Fajarda e Erra, Centro (Coruche)',
#   'nbaths': '2',
#   'nrooms': '3',
#   'price': '130 000 EUR',
#   'ref': 'C0405-00119',
#   'state_prop': 'Bom',
#   'state_sale': 'Venda',
#   'type_prop': 'Moradia',
#   'usefull_area': '160'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '763',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/jkrj4345_acdb2b47-12c2-4dd2-a42b-c09b42899ced.JPG',
#   'link': 2028145,
#   'location': 'Portugal, Guarda, Figueira de Castelo Rodrigo, Almofala e Escarigo',
#   'nbaths': '2',
#   'nrooms': '5',
#   'price': '160 000 EUR',
#   'ref': 'C0203-01555',
#   'state_prop': 'Bom',
#   'state_sale': 'Venda',
#   'type_prop': 'Moradia',
#   'usefull_area': '220'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '355',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/lateral_55dfb8ef-0041-47f1-ab32-28aa548be99b.jpg',
#   'link': 2030123,
#   'location': 'Portugal, Porto, Vila Nova de Gaia, Madalena',
#   'nbaths': '3',
#   'nrooms': '4',
#   'price': '690 000 EUR',
#   'ref': 'C0414-00093',
#   'state_prop': 'Bom',
#   'state_sale': 'Venda',
#   'type_prop': 'Moradia',
#   'usefull_area': '355'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '350',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/img-6463_31fcdf6e-d812-4bf5-9ec7-d2381b189cf1.JPG',
#   'link': 2030382,
#   'location': 'Portugal, Ilha da Madeira (Madeira), Santa Cruz (Madeira), Camacha (Madeira), Casais D Alem (Madeira)',
#   'nbaths': '4',
#   'nrooms': '4',
#   'price': '165 000 EUR',
#   'ref': 'C0216-02208',
#   'state_prop': 'Bom',
#   'state_sale': 'Venda',
#   'type_prop': 'Moradia',
#   'usefull_area': '280'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '142',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/moradia-azeitao-4_5c3aa11a-0f58-4b8d-a579-90597d211a9a.jpg',
#   'link': 2030421,
#   'location': 'Portugal, Setubal, Setubal, Azeitao (Sao Lourenco e Sao Simao)',
#   'nbaths': '3',
#   'nrooms': '3',
#   'price': '205 000 EUR',
#   'ref': 'C0405-00120',
#   'state_prop': 'Bom',
#   'state_sale': 'Venda',
#   'type_prop': 'Moradia',
#   'usefull_area': '128'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '101',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/2_09b46f20-127d-4dbf-a460-c967eff52571.jpg',
#   'link': 2015575,
#   'location': 'Portugal, Faro (Algarve), Olhao (Algarve), Moncarapacho e Fuseta (Algarve), Alfandanga (Fuseta) (Algarve)',
#   'nbaths': '1',
#   'nrooms': '3',
#   'price': '158 000 EUR',
#   'ref': 'C0254-01171',
#   'state_prop': 'Bom',
#   'state_sale': 'Venda',
#   'type_prop': 'Moradia',
#   'usefull_area': '82'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '5 050',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/constantino_e54fa47d-5a7b-4a9d-9932-5f7164d2372e.jpg',
#   'link': 2019030,
#   'location': 'Portugal, Faro (Algarve), Faro (Algarve), Santa Barbara de Nexe (Algarve), Gorjoes (Algarve)',
#   'nbaths': '0',
#   'nrooms': '4',
#   'price': '267 500 EUR',
#   'ref': 'C0358-00388',
#   'state_prop': 'Bom',
#   'state_sale': 'Venda',
#   'type_prop': 'Moradia',
#   'usefull_area': '250'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '820',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/dji-0058_eec9887c-8602-402f-a088-a6756287c084.JPG',
#   'link': 2022741,
#   'location': 'Portugal, Coimbra, Arganil, Cerdeira e Moura da Serra',
#   'nbaths': '3',
#   'nrooms': '3',
#   'price': '435 000 EUR',
#   'ref': 'C0263-00868',
#   'state_prop': 'Bom',
#   'state_sale': 'Venda',
#   'type_prop': 'Moradia',
#   'usefull_area': '372'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '968',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/img-3169_4c5df94a-1802-4ff9-9d50-fcb3f4a7f82e.jpg',
#   'link': 2025189,
#   'location': 'Portugal, Setubal, Seixal, Fernao Ferro, Vila Alegre',
#   'nbaths': '3',
#   'nrooms': '4',
#   'price': '550 000 EUR',
#   'ref': 'C0242-01628',
#   'state_prop': 'Bom',
#   'state_sale': 'Venda',
#   'type_prop': 'Moradia',
#   'usefull_area': '240'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '126',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/20200310-123622_13fbb85a-b7b8-4fd1-bff7-9f449684ac59.jpg',
#   'link': 2025439,
#   'location': 'Portugal, Setubal, Palmela, Quinta do Anjo, Quinta do Anjo',
#   'nbaths': '1',
#   'nrooms': '1',
#   'price': '94 000 EUR',
#   'ref': 'C0237-01733',
#   'state_prop': 'Bom',
#   'state_sale': 'Venda',
#   'type_prop': 'Moradia',
#   'usefull_area': '50'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '360',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/unnamed_02e2c19f-e214-4223-9da0-446438175e6a.jpg',
#   'link': 2026086,
#   'location': 'Portugal, Setubal, Palmela, Palmela, Aires',
#   'nbaths': '3',
#   'nrooms': '4',
#   'price': '349 000 EUR',
#   'ref': 'C0237-01735',
#   'state_prop': 'Bom',
#   'state_sale': 'Venda',
#   'type_prop': 'Moradia',
#   'usefull_area': '229'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '151',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/dsc-9431_fc17d61b-8656-4a36-b624-bd2999435e4a.jpg',
#   'link': 2026127,
#   'location': 'Portugal, Lisboa, Oeiras, Barcarena, Valejas',
#   'nbaths': '1',
#   'nrooms': '3',
#   'price': '297 500 EUR',
#   'ref': 'C0212-03717',
#   'state_prop': 'Bom',
#   'state_sale': 'Venda',
#   'type_prop': 'Moradia',
#   'usefull_area': '151'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '720',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/p1040743-11adc7af-85db-4182-9f00-051e59433f5f_ed8390df-9b07-4cec-81b5-fa2d6aa427b2.JPG',
#   'link': 2027243,
#   'location': 'Portugal, Lisboa, Loures, Loures, Fonte Santa',
#   'nbaths': '3',
#   'nrooms': '5',
#   'price': '499 000 EUR',
#   'ref': 'C0362-00185',
#   'state_prop': 'Bom',
#   'state_sale': 'Venda',
#   'type_prop': 'Moradia',
#   'usefull_area': '245'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '290',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/img-1365alma7_b22342ea-8fbc-4a65-a52b-753ea9cdccaf.JPG',
#   'link': 2027345,
#   'location': 'Portugal, Viseu, Mortagua, Mortagua Vale de Remigio Cortegaca e Almaca',
#   'nbaths': '0',
#   'nrooms': '0',
#   'price': '45 000 EUR',
#   'ref': 'C0396-00037',
#   'state_prop': 'Bom',
#   'state_sale': 'Venda',
#   'type_prop': 'Moradia',
#   'usefull_area': '210'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '400',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/img-1822_1b4f19ff-8fef-4617-8dd5-2bf22c1a2786.JPG',
#   'link': 2029606,
#   'location': 'Portugal, Lisboa, Cascais, Alcabideche',
#   'nbaths': '2',
#   'nrooms': '6',
#   'price': '250 000 EUR',
#   'ref': 'C0213-00768',
#   'state_prop': 'Bom',
#   'state_sale': 'Venda',
#   'type_prop': 'Moradia',
#   'usefull_area': '290'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '277',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/20200306-180543_6e0195a0-326d-4ede-b8cb-bdd1bc5facc9.jpg',
#   'link': 1982015,
#   'location': 'Portugal, Evora, Vila Vicosa, Nossa Senhora da Conceicao e Sao Bartolomeu',
#   'nbaths': '3',
#   'nrooms': '3',
#   'price': '250 000 EUR',
#   'ref': 'C0185-02304',
#   'state_prop': 'Bom',
#   'state_sale': 'Venda',
#   'type_prop': 'Moradia',
#   'usefull_area': '186'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '175',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/01_16e69877-ad14-4cc7-9c72-bf4b731dcc9b.JPG',
#   'link': 1173753,
#   'location': 'Portugal, Lisboa, Cascais, Alcabideche, Alcabideche',
#   'nbaths': '3',
#   'nrooms': '4',
#   'price': '385 000 EUR',
#   'ref': '1356-01312',
#   'state_prop': 'Bom',
#   'state_sale': 'Venda',
#   'type_prop': 'Moradia',
#   'usefull_area': '142'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '228',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/frente_98cb465f-2592-4b6f-a722-6df5dbd893dc.jpg',
#   'link': 1940375,
#   'location': 'Portugal, Portalegre, Gaviao, Comenda',
#   'nbaths': '2',
#   'nrooms': '4',
#   'price': '90 000 EUR',
#   'ref': '1782-01630',
#   'state_prop': 'Bom',
#   'state_sale': 'Venda',
#   'type_prop': 'Moradia',
#   'usefull_area': '138'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '1 024',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/img-7799_ef3f495e-9a16-45b7-a8cd-99924be137fe.JPG',
#   'link': 1997446,
#   'location': 'Portugal, Porto, Povoa de Varzim, Balazar',
#   'nbaths': '8',
#   'nrooms': '11',
#   'price': '399 800 EUR',
#   'ref': 'C0272-00860',
#   'state_prop': 'Bom',
#   'state_sale': 'Venda',
#   'type_prop': 'Moradia',
#   'usefull_area': '410'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '1 835',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/frente-a_52ac39bc-f9ac-468c-b37d-f82d979297a5.jpg',
#   'link': 2007856,
#   'location': 'Portugal, Braga, Esposende, Forjaes',
#   'nbaths': '1',
#   'nrooms': '3',
#   'price': '149 000 EUR',
#   'ref': 'C0368-00126',
#   'state_prop': 'Bom',
#   'state_sale': 'Venda',
#   'type_prop': 'Moradia',
#   'usefull_area': '135'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '283',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/fachada1002_87386bc5-050c-4085-a3fa-90987b042aac.JPG',
#   'link': 2011223,
#   'location': 'Portugal, Aveiro, Aveiro, Aradas, Verdemilho',
#   'nbaths': '3',
#   'nrooms': '3',
#   'price': '269 500 EUR',
#   'ref': 'C0385-00093',
#   'state_prop': 'Bom',
#   'state_sale': 'Venda',
#   'type_prop': 'Moradia',
#   'usefull_area': '162'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '259',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/sala01_8448d617-22d5-457b-911b-5dc0cfa7f334.jpg',
#   'link': 2019551,
#   'location': 'Portugal, Porto, Valongo, Alfena, Intermarche',
#   'nbaths': '4',
#   'nrooms': '4',
#   'price': '265 000 EUR',
#   'ref': 'C0272-00858',
#   'state_prop': 'Bom',
#   'state_sale': 'Venda',
#   'type_prop': 'Moradia',
#   'usefull_area': '259'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '3 430',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/dji-0042_fc0a47a5-788e-41cc-9bb4-9caf0fdc6dc7.jpg',
#   'link': 2019765,
#   'location': 'Portugal, Leiria, Leiria, Maceira',
#   'nbaths': '2',
#   'nrooms': '3',
#   'price': '168 000 EUR',
#   'ref': 'C0355-00388',
#   'state_prop': 'Bom',
#   'state_sale': 'Venda',
#   'type_prop': 'Moradia',
#   'usefull_area': '394'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '127',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/-dsf8373_ab620db6-f0f7-49e2-bc61-9a6106c67982.jpg',
#   'link': 2023078,
#   'location': 'Portugal, Setubal, Sesimbra, Quinta do Conde, Conde Iii',
#   'nbaths': '2',
#   'nrooms': '3',
#   'price': '225 000 EUR',
#   'ref': '1072-03105',
#   'state_prop': 'Bom',
#   'state_sale': 'Venda',
#   'type_prop': 'Moradia',
#   'usefull_area': '120'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '300',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/moradia_46cc1e0c-b7bd-4b3b-a942-132724a5f680.PNG',
#   'link': 2024167,
#   'location': 'Portugal, Lisboa, Oeiras, Oeiras e S.Juliao da Barra Paco de Arcos e Caxias, Oeiras',
#   'nbaths': '4',
#   'nrooms': '3',
#   'price': '880 000 EUR',
#   'ref': '1649-00932',
#   'state_prop': 'Bom',
#   'state_sale': 'Venda',
#   'type_prop': 'Moradia',
#   'usefull_area': '282'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '167',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/moradias_ba0aa497-808e-4716-b4ad-85ae8c584fe4.PNG',
#   'link': 2024216,
#   'location': 'Portugal, Lisboa, Oeiras, Oeiras e S.Juliao da Barra Paco de Arcos e Caxias, Oeiras',
#   'nbaths': '4',
#   'nrooms': '3',
#   'price': '800 000 EUR',
#   'ref': '1649-00934',
#   'state_prop': 'Bom',
#   'state_sale': 'Venda',
#   'type_prop': 'Moradia',
#   'usefull_area': '293'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '167',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/oeiras3_54b2959e-dcd3-42cf-8c87-057d3b38b672.PNG',
#   'link': 2024691,
#   'location': 'Portugal, Lisboa, Oeiras, Oeiras e S.Juliao da Barra Paco de Arcos e Caxias, Centro Historico',
#   'nbaths': '4',
#   'nrooms': '3',
#   'price': '800 000 EUR',
#   'ref': '1649-00933',
#   'state_prop': 'Bom',
#   'state_sale': 'Venda',
#   'type_prop': 'Moradia',
#   'usefull_area': '293'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '275',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/-mg-7773_27e85e0a-495b-40e6-ae26-4ca92e30b0b2.jpg',
#   'link': 2026132,
#   'location': 'Portugal, Setubal, Seixal, Seixal Arrentela e Aldeia de Paio Pires, Quinta do Pe Leve',
#   'nbaths': '3',
#   'nrooms': '4',
#   'price': '339 000 EUR',
#   'ref': '0651-03030',
#   'state_prop': 'Bom',
#   'state_sale': 'Venda',
#   'type_prop': 'Moradia',
#   'usefull_area': '175'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '60',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/thumbnail-img-20200302-wa0050_2b0afb07-7cff-4ee4-9b63-a68d933f8514.jpg',
#   'link': 2026143,
#   'location': 'Portugal, Porto, Vila do Conde, Vila do Conde, Caxinas',
#   'nbaths': '1',
#   'nrooms': '3',
#   'price': '79 000 EUR',
#   'ref': 'C0251-01386',
#   'state_prop': 'Bom',
#   'state_sale': 'Venda',
#   'type_prop': 'Moradia',
#   'usefull_area': '60'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '76',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/p1150039_5f54bb76-a586-4cc1-8bf2-7937bc112fd8.JPG',
#   'link': 2028230,
#   'location': 'Portugal, Faro (Algarve), Vila do Bispo (Algarve), Vila do Bispo e Raposeira (Algarve)',
#   'nbaths': '0',
#   'nrooms': '3',
#   'price': '78 000 EUR',
#   'ref': 'C0369-00151',
#   'state_prop': 'Bom',
#   'state_sale': 'Venda',
#   'type_prop': 'Moradia',
#   'usefull_area': '60'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '154',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/received-2644329995693736_755f1a04-5a64-4f73-9f00-515a17cd1743.jpg',
#   'link': 2028524,
#   'location': 'Portugal, Aveiro, Aveiro, Esgueira',
#   'nbaths': '2',
#   'nrooms': '2',
#   'price': '150 000 EUR',
#   'ref': 'C0385-00096',
#   'state_prop': 'Bom',
#   'state_sale': 'Venda',
#   'type_prop': 'Moradia',
#   'usefull_area': '144'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '283',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/88138941-219601062760426-5390014880797425664-n_9c676316-47d2-463d-80ca-98dad2d5fec3.jpg',
#   'link': 2028581,
#   'location': 'Portugal, Porto, Vila do Conde, Azurara',
#   'nbaths': '2',
#   'nrooms': '3',
#   'price': '94 500 EUR',
#   'ref': 'C0251-01385',
#   'state_prop': 'Bom',
#   'state_sale': 'Venda',
#   'type_prop': 'Moradia',
#   'usefull_area': '170'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '305',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/img-20190323-wa0063_25cd2567-c4b0-4f76-976b-8ccdc31cc193.jpg',
#   'link': 2028586,
#   'location': 'Portugal, Porto, Porto, Paranhos, Antas',
#   'nbaths': '5',
#   'nrooms': '6',
#   'price': '800 000 EUR',
#   'ref': 'C0412-00124',
#   'state_prop': 'Bom',
#   'state_sale': 'Venda',
#   'type_prop': 'Moradia',
#   'usefull_area': '163'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '519',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/0871_6572b004-ad00-4ac9-a7fa-8be6c66b504a.JPG',
#   'link': 2028644,
#   'location': 'Portugal, Setubal, Setubal, Azeitao (Sao Lourenco e Sao Simao), Azeitao',
#   'nbaths': '3',
#   'nrooms': '4',
#   'price': '325 000 EUR',
#   'ref': 'C0237-01728',
#   'state_prop': 'Bom',
#   'state_sale': 'Venda',
#   'type_prop': 'Moradia',
#   'usefull_area': '198'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '164',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/dscf4744_654aebb8-ee51-40fc-88b1-0f4c497a3eeb.jpg',
#   'link': 2029003,
#   'location': 'Portugal, Faro (Algarve), Albufeira (Algarve), Albufeira e Olhos de Agua (Algarve), Sao Rafael (Albufeira) (Algarve)',
#   'nbaths': '2',
#   'nrooms': '2',
#   'price': '340 000 EUR',
#   'ref': 'C0237-01730',
#   'state_prop': 'Bom',
#   'state_sale': 'Venda',
#   'type_prop': 'Moradia',
#   'usefull_area': '121'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '310',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/img-20150405-165306-1-_dc360135-9cc8-442f-a1b5-48faeba96bcb.jpg',
#   'link': 1925257,
#   'location': 'Portugal, Setubal, Seixal, Fernao Ferro, Pinhal do General',
#   'nbaths': '3',
#   'nrooms': '4',
#   'price': '250 000 EUR',
#   'ref': '0651-03023',
#   'state_prop': 'Bom',
#   'state_sale': 'Venda',
#   'type_prop': 'Moradia',
#   'usefull_area': '286'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '187',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/whatsapp-image-2020-03-10-at-17-56-45_221c4f3a-986a-495c-a246-b8e9306f6e8d.jpg',
#   'link': 1941040,
#   'location': 'Portugal, Porto, Porto, Paranhos, Costa Cabral',
#   'nbaths': '2',
#   'nrooms': '2',
#   'price': '395 000 EUR',
#   'ref': 'C0243-01429',
#   'state_prop': 'Bom',
#   'state_sale': 'Venda',
#   'type_prop': 'Moradia',
#   'usefull_area': '85'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '180',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/img-9412_55d2d6a0-3108-43cf-bdb7-020f2529fb18.jpg',
#   'link': 1985526,
#   'location': 'Portugal, Setubal, Seixal, Amora, Qta. da Charnequinha',
#   'nbaths': '3',
#   'nrooms': '3',
#   'price': '272 000 EUR',
#   'ref': '0651-03022',
#   'state_prop': 'Bom',
#   'state_sale': 'Venda',
#   'type_prop': 'Moradia',
#   'usefull_area': '156'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '3 600',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/fernando-martins-85_f47c3a77-9d8a-4db9-a3cc-7dd49c66bcb4.jpg',
#   'link': 2005559,
#   'location': 'Portugal, Leiria, Pombal, Abiul',
#   'nbaths': '5',
#   'nrooms': '4',
#   'price': '1 500 000 EUR',
#   'ref': 'C0372-00222',
#   'state_prop': 'Bom',
#   'state_sale': 'Venda',
#   'type_prop': 'Moradia',
#   'usefull_area': '639'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '103',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/dscn0120_ecf61edc-ab1a-44cb-9c05-a169e23cd8d7.JPG',
#   'link': 2015153,
#   'location': 'Portugal, Santarem, Santarem, Achete Azoia de Baixo e Povoa de Santarem, Centro (Azoia de Baixo)',
#   'nbaths': '1',
#   'nrooms': '3',
#   'price': '70 000 EUR',
#   'ref': '1780-02287',
#   'state_prop': 'Bom',
#   'state_sale': 'Venda',
#   'type_prop': 'Moradia',
#   'usefull_area': '93'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '321',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/c98b4e85-7467-49c8-8649-61ca53dac9c0_3d524c3f-f22a-404a-9dbc-a7437e56e668.jpg',
#   'link': 2015827,
#   'location': 'Portugal, Porto, Valongo, Ermesinde, Santa Rita',
#   'nbaths': '2',
#   'nrooms': '3',
#   'price': '175 000 EUR',
#   'ref': 'C0243-01428',
#   'state_prop': 'Bom',
#   'state_sale': 'Venda',
#   'type_prop': 'Moradia',
#   'usefull_area': '136'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '336',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/85255010-191320905269902-147356303541403648-n_5648a31e-a0e0-4ad0-bd8b-fa866c71bcfc.jpg',
#   'link': 2017253,
#   'location': 'Portugal, Ilha de Sao Miguel (Acores), Ponta Delgada (Acores), Mosteiros (Acores)',
#   'nbaths': '1',
#   'nrooms': '1',
#   'price': '60 000 EUR',
#   'ref': 'C0276-01111',
#   'state_prop': 'Bom',
#   'state_sale': 'Venda',
#   'type_prop': 'Moradia',
#   'usefull_area': '134'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '234',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/img-2871_6ddf6737-74d8-4685-9e4e-790cf6f895a8.jpg',
#   'link': 2019814,
#   'location': 'Portugal, Porto, Porto, Paranhos, Hospital de Sao Joao',
#   'nbaths': '3',
#   'nrooms': '4',
#   'price': '290 000 EUR',
#   'ref': 'C0415-00010',
#   'state_prop': 'Bom',
#   'state_sale': 'Venda',
#   'type_prop': 'Moradia',
#   'usefull_area': '150'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '970',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/dsc07145_371c8d8f-b3d1-41cd-bb59-55fd67a9124d.jpg',
#   'link': 2019900,
#   'location': 'Portugal, Coimbra, Mira, Praia de Mira',
#   'nbaths': '3',
#   'nrooms': '4',
#   'price': '470 000 EUR',
#   'ref': 'C0288-00294',
#   'state_prop': 'Bom',
#   'state_sale': 'Venda',
#   'type_prop': 'Moradia',
#   'usefull_area': '349'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '906',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/dji-0011_e5f54b20-b9cf-40a1-8735-a90787ed64f8.jpg',
#   'link': 2020477,
#   'location': 'Portugal, Setubal, Grandola, Carvalhal, Urbanizacao Soltroia',
#   'nbaths': '6',
#   'nrooms': '5',
#   'price': '2 250 000 EUR',
#   'ref': 'C0410-00012',
#   'state_prop': 'Bom',
#   'state_sale': 'Venda',
#   'type_prop': 'Moradia',
#   'usefull_area': '390'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '158',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/whatsapp-image-2020-02-19-at-12-15-39_cbeb8aba-face-4238-b8a5-c7f9e88ba298.jpg',
#   'link': 2020669,
#   'location': 'Portugal, Setubal, Sesimbra, Quinta do Conde',
#   'nbaths': '2',
#   'nrooms': '3',
#   'price': '170 000 EUR',
#   'ref': '1072-03103',
#   'state_prop': 'Bom',
#   'state_sale': 'Venda',
#   'type_prop': 'Moradia',
#   'usefull_area': '108'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '280',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/maison_038e7601-2527-4f1b-8f53-362d44d86b4d.jpg',
#   'link': 2023396,
#   'location': 'Portugal, Faro (Algarve), Lagoa (Algarve), Lagoa e Carvoeiro (Algarve), Centro (Algarve)',
#   'nbaths': '2',
#   'nrooms': '3',
#   'price': '450 000 EUR',
#   'ref': 'C0240-01903',
#   'state_prop': 'Bom',
#   'state_sale': 'Venda',
#   'type_prop': 'Moradia',
#   'usefull_area': '354'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '120',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/soc-1_beeef57d-2d53-41e4-b56c-43845b2b0ed2.JPG',
#   'link': 2024632,
#   'location': 'Portugal, Porto, Vila do Conde, Vila do Conde, Centro',
#   'nbaths': '1',
#   'nrooms': '2',
#   'price': '130 000 EUR',
#   'ref': 'C0413-00163',
#   'state_prop': 'Bom',
#   'state_sale': 'Venda',
#   'type_prop': 'Moradia',
#   'usefull_area': '100'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '1 139',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/dsc-3118_bb0c7724-1390-4f9f-8b4b-9e54cd4f28fa.jpg',
#   'link': 2025697,
#   'location': 'Portugal, Porto, Matosinhos, Matosinhos e Leca da Palmeira',
#   'nbaths': '6',
#   'nrooms': '6',
#   'price': '1 600 000 EUR',
#   'ref': 'C0406-00102',
#   'state_prop': 'Bom',
#   'state_sale': 'Venda',
#   'type_prop': 'Moradia',
#   'usefull_area': '518'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '350',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/moradia-cascais-1-_2a65951d-0fe7-4266-9d19-d9d821fed15b.jpg',
#   'link': 2027159,
#   'location': 'Portugal, Lisboa, Cascais, Alcabideche, Bicesse',
#   'nbaths': '4',
#   'nrooms': '4',
#   'price': '795 000 EUR',
#   'ref': 'C0405-00115',
#   'state_prop': 'Bom',
#   'state_sale': 'Venda',
#   'type_prop': 'Moradia',
#   'usefull_area': '200'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '240',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/foto1sonia_4015b471-875a-4470-8f42-22a1f789a765.jpg',
#   'link': 1972269,
#   'location': 'Portugal, Leiria, Nazare, Nazare, Rio Novo',
#   'nbaths': '2',
#   'nrooms': '3',
#   'price': '140 000 EUR',
#   'ref': '1739-01304',
#   'state_prop': 'Bom',
#   'state_sale': 'Vendido',
#   'type_prop': 'Moradia',
#   'usefull_area': '166'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '240',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/img-3281_c740c9c2-98c6-4546-960a-1ed371f15647.jpg',
#   'link': 2012985,
#   'location': 'Portugal, Leiria, Leiria, Parceiros e Azoia',
#   'nbaths': '2',
#   'nrooms': '2',
#   'price': '186 000 EUR',
#   'ref': 'C0355-00385',
#   'state_prop': 'Bom',
#   'state_sale': 'Venda',
#   'type_prop': 'Moradia',
#   'usefull_area': '231'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '3 967',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/20200221-150419_ce6cc805-a050-4ff5-a727-2a6af124e0c3.jpg',
#   'link': 2025156,
#   'location': 'Portugal, Viseu, Mangualde, Alcafache',
#   'nbaths': '1',
#   'nrooms': '3',
#   'price': '140 000 EUR',
#   'ref': 'C0203-01551',
#   'state_prop': 'Bom',
#   'state_sale': 'Venda',
#   'type_prop': 'Moradia',
#   'usefull_area': '251'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '70',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/t1-dias-fernandes-alexgaspar-alx0166_76ac021d-d593-4502-8954-8303ad5f8c30.jpg',
#   'link': 2025834,
#   'location': 'Portugal, Setubal, Setubal, S.Juliao N.Sao da Anunciada e S.Maria da Graca, Anunciada (Nossa Senhora da Anunciada)',
#   'nbaths': '2',
#   'nrooms': '1',
#   'price': '128 000 EUR',
#   'ref': 'C0237-01727',
#   'state_prop': 'Bom',
#   'state_sale': 'Venda',
#   'type_prop': 'Moradia',
#   'usefull_area': '36'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '150',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/1_66dcf5bf-032d-4019-a253-fb1c1f1b80b7.jpg',
#   'link': 2026077,
#   'location': 'Portugal, Setubal, Montijo, Montijo e Afonsoeiro',
#   'nbaths': '1',
#   'nrooms': '2',
#   'price': '240 000 EUR',
#   'ref': 'C0223-02765',
#   'state_prop': 'Bom',
#   'state_sale': 'Venda',
#   'type_prop': 'Moradia',
#   'usefull_area': '125'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '360',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/whatsapp-image-2019-12-17-at-21-28-45_d6a6d215-b86a-47b2-ab6a-af04e8c51fa8.jpg',
#   'link': 1997969,
#   'location': 'Portugal, Setubal, Montijo, Atalaia e Alto Estanqueiro-Jardia, Atalaia',
#   'nbaths': '3',
#   'nrooms': '3',
#   'price': '430 000 EUR',
#   'ref': 'C0383-00139',
#   'state_prop': 'Bom',
#   'state_sale': 'Venda',
#   'type_prop': 'Moradia',
#   'usefull_area': '202'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '308',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/-107-_e8b0d370-d31e-4e80-9934-0e35ffb79ecc.jpg',
#   'link': 2000862,
#   'location': 'Portugal, Coimbra, Lousa, Gandaras',
#   'nbaths': '1',
#   'nrooms': '2',
#   'price': '27 500 EUR',
#   'ref': 'C0289-00609',
#   'state_prop': 'Bom',
#   'state_sale': 'Venda',
#   'type_prop': 'Moradia',
#   'usefull_area': '188'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '13 000',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/p152-27-_3c537f06-3d44-4ee9-92dc-3891a5baff34.jpg',
#   'link': 2015580,
#   'location': 'Portugal, Coimbra, Condeixa-A-Nova, Zambujal, Zambujal',
#   'nbaths': '2',
#   'nrooms': '3',
#   'price': '199 999 EUR',
#   'ref': 'C0383-00138',
#   'state_prop': 'Bom',
#   'state_sale': 'Venda',
#   'type_prop': 'Moradia',
#   'usefull_area': '175'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '155',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/20200204-163642_37e0a980-2bfb-49b2-9f20-fb46ae5d4bf5.jpg',
#   'link': 2019309,
#   'location': 'Portugal, Setubal, Sesimbra, Quinta do Conde, Quinta do Conde',
#   'nbaths': '2',
#   'nrooms': '3',
#   'price': '254 900 EUR',
#   'ref': '1072-03100',
#   'state_prop': 'Bom',
#   'state_sale': 'Venda',
#   'type_prop': 'Moradia',
#   'usefull_area': '150'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '3 798',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/tregosa4-8b39d632-1302-4ae9-b630-3f45f48d2751_fd68db96-32bb-49c2-b7d2-aabee9ce0d46.jpg',
#   'link': 2023075,
#   'location': 'Portugal, Braga, Barcelos, Durraes e Tregosa',
#   'nbaths': '1',
#   'nrooms': '3',
#   'price': '130 000 EUR',
#   'ref': 'C0258-01140',
#   'state_prop': 'Bom',
#   'state_sale': 'Venda',
#   'type_prop': 'Moradia',
#   'usefull_area': '105'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '2 030',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/img-6405_6ff3e7c5-bac1-432f-83f5-8e500e75d47e.JPG',
#   'link': 2024679,
#   'location': 'Portugal, Ilha da Madeira (Madeira), Funchal (Madeira), Sao Martinho (Madeira), Amparo (Madeira)',
#   'nbaths': '4',
#   'nrooms': '4',
#   'price': '726 000 EUR',
#   'ref': 'C0216-02206',
#   'state_prop': 'Bom',
#   'state_sale': 'Venda',
#   'type_prop': 'Moradia',
#   'usefull_area': '540'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '350',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/moradia-ericeira-26_fa6efd3e-d0d1-4caa-b25e-c0e68b859006.jpg',
#   'link': 2025490,
#   'location': 'Portugal, Lisboa, Mafra, Santo Isidoro',
#   'nbaths': '1',
#   'nrooms': '2',
#   'price': '250 000 EUR',
#   'ref': 'C0405-00113',
#   'state_prop': 'Bom',
#   'state_sale': 'Venda',
#   'type_prop': 'Moradia',
#   'usefull_area': '90'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '3 800',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/10_ab5c97bf-ebd6-4d51-93fc-cbb8857480d4.jpg',
#   'link': 2026061,
#   'location': 'Portugal, Faro (Algarve), Albufeira (Algarve), Guia (Algarve)',
#   'nbaths': '1',
#   'nrooms': '4',
#   'price': '290 000 EUR',
#   'ref': 'C0205-04329',
#   'state_prop': 'Bom',
#   'state_sale': 'Venda',
#   'type_prop': 'Moradia',
#   'usefull_area': '100'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '435',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/-dsf8770_017ddd43-f6e1-4a9a-bbed-4a6769996987.jpg',
#   'link': 2026135,
#   'location': 'Portugal, Setubal, Sesimbra, Quinta do Conde, Quinta do Peru',
#   'nbaths': '5',
#   'nrooms': '4',
#   'price': '770 000 EUR',
#   'ref': '1072-03101',
#   'state_prop': 'Bom',
#   'state_sale': 'Venda',
#   'type_prop': 'Moradia',
#   'usefull_area': '301'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '841',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/img-5388-89-90-jardim-piscina-e-casa-jpg_15254dd4-94af-495e-8fe1-f52712c3b09c.jpg',
#   'link': 2026412,
#   'location': 'Portugal, Lisboa, Lisboa, Campolide, Campolide',
#   'nbaths': '4',
#   'nrooms': '4',
#   'price': '2 950 000 EUR',
#   'ref': 'C0378-00049',
#   'state_prop': 'Bom',
#   'state_sale': 'Venda',
#   'type_prop': 'Moradia',
#   'usefull_area': '343'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '158',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/1_b173b1df-a1ed-43b7-bbdf-6e78ac1b193d.JPG',
#   'link': 2026460,
#   'location': 'Portugal, Lisboa, Sintra, Sao Joao das Lampas e Terrugem, A-Do-Longo',
#   'nbaths': '2',
#   'nrooms': '2',
#   'price': '246 000 EUR',
#   'ref': 'C0290-00132',
#   'state_prop': 'Bom',
#   'state_sale': 'Venda',
#   'type_prop': 'Moradia',
#   'usefull_area': '98'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '186',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/04-6-_d76617ac-370d-462f-84d0-5f983514556a.jpg',
#   'link': 2027065,
#   'location': 'Portugal, Lisboa, Sintra, Algueirao-Mem Martins, Algueirao',
#   'nbaths': '2',
#   'nrooms': '6',
#   'price': '335 000 EUR',
#   'ref': '1747-01466',
#   'state_prop': 'Bom',
#   'state_sale': 'Venda',
#   'type_prop': 'Moradia',
#   'usefull_area': '186'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '165',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/whatsapp-image-2019-11-21-at-17-22-47_289ae0ab-eee0-4d7f-acee-6e2298e128b3.jpg',
#   'link': 1885368,
#   'location': 'Portugal, Setubal, Setubal, Azeitao (Sao Lourenco e Sao Simao), Azeitao',
#   'nbaths': '2',
#   'nrooms': '3',
#   'price': '227 000 EUR',
#   'ref': '1072-03095',
#   'state_prop': 'Bom',
#   'state_sale': 'Venda',
#   'type_prop': 'Moradia',
#   'usefull_area': '122'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '165',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/img-3864_d666218d-40cf-4af0-9b61-946dcef2cea8.JPG',
#   'link': 2003324,
#   'location': 'Portugal, Setubal, Seixal, Corroios, Alto do Moinho',
#   'nbaths': '1',
#   'nrooms': '4',
#   'price': '185 000 EUR',
#   'ref': 'C0242-01627',
#   'state_prop': 'Bom',
#   'state_sale': 'Venda',
#   'type_prop': 'Moradia',
#   'usefull_area': '135'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '523',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/1_d14711d5-6293-4aa0-ae1e-997868a20ff4.jpg',
#   'link': 2009136,
#   'location': 'Portugal, Leiria, Marinha Grande, Marinha Grande, Ordem',
#   'nbaths': '4',
#   'nrooms': '3',
#   'price': '189 900 EUR',
#   'ref': '1746-01285',
#   'state_prop': 'Bom',
#   'state_sale': 'Venda',
#   'type_prop': 'Moradia',
#   'usefull_area': '285'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '352',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/moradia-calvaria_f509c20b-a491-4538-a88f-927672eb19c9.jpg',
#   'link': 2009917,
#   'location': 'Portugal, Leiria, Porto de Mos, Calvaria de Cima',
#   'nbaths': '1',
#   'nrooms': '3',
#   'price': '115 000 EUR',
#   'ref': '1746-01284',
#   'state_prop': 'Bom',
#   'state_sale': 'Venda',
#   'type_prop': 'Moradia',
#   'usefull_area': '146'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '290',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/moradia-arcozelo-56_0e8fba63-5b10-4c86-9843-fc40e8c80876.jpg',
#   'link': 2018277,
#   'location': 'Portugal, Porto, Vila Nova de Gaia, Serzedo e Perosinho, Gaia Sul (Perosinho)',
#   'nbaths': '4',
#   'nrooms': '3',
#   'price': '480 000 EUR',
#   'ref': 'C0243-01422',
#   'state_prop': 'Bom',
#   'state_sale': 'Venda',
#   'type_prop': 'Moradia',
#   'usefull_area': '240'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '286',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/image-02-novo_f0c11b83-db13-4f9e-8ab7-c01108b116bb.png',
#   'link': 2018947,
#   'location': 'Portugal, Lisboa, Oeiras, Oeiras e S.Juliao da Barra Paco de Arcos e Caxias, Quinta do Torneiro',
#   'nbaths': '5',
#   'nrooms': '4',
#   'price': '750 000 EUR',
#   'ref': 'C0212-03714',
#   'state_prop': 'Bom',
#   'state_sale': 'Venda',
#   'type_prop': 'Moradia',
#   'usefull_area': '208'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '60',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/-137-_d9d85999-3c92-4aa9-9293-2313f6de2c86.jpg',
#   'link': 2022563,
#   'location': 'Portugal, Coimbra, Gois, Cadafaz e Colmeal',
#   'nbaths': '1',
#   'nrooms': '1',
#   'price': '14 000 EUR',
#   'ref': 'C0289-00606',
#   'state_prop': 'Bom',
#   'state_sale': 'Venda',
#   'type_prop': 'Moradia',
#   'usefull_area': '40'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '42',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/-127-_2b4889d2-5c18-4c12-90c3-bb3b13e67c56.jpg',
#   'link': 2022658,
#   'location': 'Portugal, Coimbra, Gois, Cadafaz e Colmeal',
#   'nbaths': '2',
#   'nrooms': '2',
#   'price': '55 000 EUR',
#   'ref': 'C0289-00608',
#   'state_prop': 'Bom',
#   'state_sale': 'Venda',
#   'type_prop': 'Moradia',
#   'usefull_area': '42'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '198',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/p1010326-68e77cf9-14fc-470f-aa02-65f2fdf86252_e48d6c48-fff6-4d2d-88d5-38a42882d913.jpg',
#   'link': 2023250,
#   'location': 'Portugal, Portalegre, Castelo de Vide, Nossa Senhora da Graca de Povoa e Meadas',
#   'nbaths': '1',
#   'nrooms': '5',
#   'price': '99 950 EUR',
#   'ref': 'C0362-00183',
#   'state_prop': 'Bom',
#   'state_sale': 'Venda',
#   'type_prop': 'Moradia',
#   'usefull_area': '116'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '862',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/p1030187_6dbb0719-e7f5-4856-8c2e-75dc657b9830.JPG',
#   'link': 2024465,
#   'location': 'Portugal, Santarem, Santarem, Sao Vicente do Paul e Vale de Figueira, Sao Vicente de Paul',
#   'nbaths': '1',
#   'nrooms': '2',
#   'price': '35 000 EUR',
#   'ref': '0651-03015',
#   'state_prop': 'Bom',
#   'state_sale': 'Venda',
#   'type_prop': 'Moradia',
#   'usefull_area': '76'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '264',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/casa1_2725546a-4e49-4aab-8d02-7859152b0cbf.jpg',
#   'link': 2026153,
#   'location': 'Portugal, Porto, Porto, Campanha',
#   'nbaths': '3',
#   'nrooms': '2',
#   'price': '1 000 000 EUR',
#   'ref': 'C0406-00100',
#   'state_prop': 'Bom',
#   'state_sale': 'Venda',
#   'type_prop': 'Moradia',
#   'usefull_area': '264'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '226',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/1_8612a0af-38a2-4fbf-9f2e-c3050d011a58.jpg',
#   'link': 2026184,
#   'location': 'Portugal, Setubal, Seixal, Amora, Belverde',
#   'nbaths': '2',
#   'nrooms': '3',
#   'price': '295 000 EUR',
#   'ref': 'C0364-00328',
#   'state_prop': 'Bom',
#   'state_sale': 'Venda',
#   'type_prop': 'Moradia',
#   'usefull_area': '202'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '149',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/-dsf9774-jpg_f6cb08f0-29eb-4fe3-8c19-f2350cd0b016.jpg',
#   'link': 2026484,
#   'location': 'Portugal, Setubal, Sesimbra, Quinta do Conde, Conde I',
#   'nbaths': '2',
#   'nrooms': '3',
#   'price': '207 000 EUR',
#   'ref': '1072-03099',
#   'state_prop': 'Bom',
#   'state_sale': 'Venda',
#   'type_prop': 'Moradia',
#   'usefull_area': '119'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '425',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/dscn4085_6dc0c985-dbf5-4484-8a02-01e91c202a56.JPG',
#   'link': 1952897,
#   'location': 'Portugal, Santarem, Vila Nova da Barquinha, Vila Nova da Barquinha',
#   'nbaths': '3',
#   'nrooms': '4',
#   'price': '260 000 EUR',
#   'ref': 'C0269-00740',
#   'state_prop': 'Bom',
#   'state_sale': 'Venda',
#   'type_prop': 'Moradia',
#   'usefull_area': '228'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '100',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/img-0980_9cc6f669-a796-4ab8-b177-1e74ad368bb0.jpg',
#   'link': 1967406,
#   'location': 'Portugal, Coimbra, Coimbra, Torres do Mondego, Casal da Misarela',
#   'nbaths': '2',
#   'nrooms': '2',
#   'price': '59 500 EUR',
#   'ref': 'C0396-00026',
#   'state_prop': 'Bom',
#   'state_sale': 'Venda',
#   'type_prop': 'Moradia',
#   'usefull_area': '93'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '78',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/rosana1_57da19c6-4649-49d0-817f-2216ba0c8fea.png',
#   'link': 2020411,
#   'location': 'Portugal, Porto, Porto, Cedofeita Ildefonso Se Miragaia Nicolau Vitoria, Lapa',
#   'nbaths': '2',
#   'nrooms': '3',
#   'price': '295 000 EUR',
#   'ref': 'C0272-00854',
#   'state_prop': 'Bom',
#   'state_sale': 'Venda',
#   'type_prop': 'Moradia',
#   'usefull_area': '78'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '3 005',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/95_6d6546b0-d73e-426c-9c65-038d03095449.jpg',
#   'link': 2021926,
#   'location': 'Portugal, Lisboa, Torres Vedras, Turcifal, Quinta de Fez',
#   'nbaths': '0',
#   'nrooms': '7',
#   'price': '1 080 000 EUR',
#   'ref': 'C0362-00180',
#   'state_prop': 'Bom',
#   'state_sale': 'Venda',
#   'type_prop': 'Moradia',
#   'usefull_area': '360'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '158',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/img-2688-89-90_3c986546-d60e-4c9e-8f09-4eec447741d5.jpg',
#   'link': 2025482,
#   'location': 'Portugal, Lisboa, Amadora, Mina de Agua, Moinhos da Funcheira (Sao Bras)',
#   'nbaths': '5',
#   'nrooms': '3',
#   'price': '465 000 EUR',
#   'ref': 'C0222-02780',
#   'state_prop': 'Bom',
#   'state_sale': 'Venda',
#   'type_prop': 'Moradia',
#   'usefull_area': '146'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '2 420',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/30378de1-b5ad-4150-bf13-4ae158b8a51c-1-105-c_bc75e784-bf15-4a8a-acda-c1d3ff967b55.jpg',
#   'link': 2025743,
#   'location': 'Portugal, Ilha da Madeira (Madeira), Calheta (Madeira), Arco da Calheta (Madeira), Fonte Bugia (Madeira)',
#   'nbaths': '1',
#   'nrooms': '4',
#   'price': '380 000 EUR',
#   'ref': 'C0215-02369',
#   'state_prop': 'Bom',
#   'state_sale': 'Venda',
#   'type_prop': 'Moradia',
#   'usefull_area': '168'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '18 000',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/img-20191030-wa0038_912a471e-ba15-4823-ae3e-af49ef9c2b5d.jpg',
#   'link': 1708682,
#   'location': 'Portugal, Evora, Mora, Brotas',
#   'nbaths': '3',
#   'nrooms': '4',
#   'price': '584 900 EUR',
#   'ref': 'C0185-02298',
#   'state_prop': 'Bom',
#   'state_sale': 'Venda',
#   'type_prop': 'Moradia',
#   'usefull_area': '200'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '1 380',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/20200204-123151_311e7eb1-862f-46d0-8770-80b06dda4120.jpg',
#   'link': 1996641,
#   'location': 'Portugal, Aveiro, Anadia, Avelas de Cima',
#   'nbaths': '1',
#   'nrooms': '2',
#   'price': '45 000 EUR',
#   'ref': 'C0288-00291',
#   'state_prop': 'Bom',
#   'state_sale': 'Venda',
#   'type_prop': 'Moradia',
#   'usefull_area': '110'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '262',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/1_9a8356cd-5e60-4d50-8b8c-f88faaa4f889.jpg',
#   'link': 1998702,
#   'location': 'Portugal, Ilha de Sao Miguel (Acores), Ponta Delgada (Acores), Ponta Delgada (Santa Clara) (Acores)',
#   'nbaths': '2',
#   'nrooms': '6',
#   'price': '320 000 EUR',
#   'ref': 'C0276-01108',
#   'state_prop': 'Bom',
#   'state_sale': 'Venda',
#   'type_prop': 'Moradia',
#   'usefull_area': '135'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '301',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/img-2820_89bd3a49-fa30-45b1-917e-8afcec7074c8.JPG',
#   'link': 2008821,
#   'location': 'Portugal, Evora, Montemor-O-Novo, Santiago do Escoural',
#   'nbaths': '1',
#   'nrooms': '3',
#   'price': '65 000 EUR',
#   'ref': 'C0185-02300',
#   'state_prop': 'Bom',
#   'state_sale': 'Venda',
#   'type_prop': 'Moradia',
#   'usefull_area': '90'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '283',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/img-20200227-wa0068-1583340916350_c6579ada-fba9-43b5-8191-2344d5630b16.jpg',
#   'link': 2010227,
#   'location': 'Portugal, Lisboa, Mafra, Santo Isidoro, Ribamar',
#   'nbaths': '3',
#   'nrooms': '3',
#   'price': '359 500 EUR',
#   'ref': 'C0246-01920',
#   'state_prop': 'Bom',
#   'state_sale': 'Venda',
#   'type_prop': 'Moradia',
#   'usefull_area': '207'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '165',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/0_f2e6f1a0-f785-44af-ba52-54495fd0c2a4.jpg',
#   'link': 2010912,
#   'location': 'Portugal, Setubal, Almada, Charneca de Caparica e Sobreda, Quintinhas',
#   'nbaths': '3',
#   'nrooms': '3',
#   'price': '298 000 EUR',
#   'ref': '0651-03013',
#   'state_prop': 'Bom',
#   'state_sale': 'Venda',
#   'type_prop': 'Moradia',
#   'usefull_area': '159'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '500',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/86809659-498773687718555-8157748280864800768-n_07e6707f-78bc-4d12-b39f-57fd1661361b.jpg',
#   'link': 2012652,
#   'location': 'Portugal, Aveiro, Oliveira de Azemeis, O. Azemeis Riba-Ul Ul Macinhata Seixa Madail, Centro (Oliveira de Azemeis)',
#   'nbaths': '3',
#   'nrooms': '4',
#   'price': '225 000 EUR',
#   'ref': 'C0385-00092',
#   'state_prop': 'Bom',
#   'state_sale': 'Venda',
#   'type_prop': 'Moradia',
#   'usefull_area': '250'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '181',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/1-filipecorreia-esmeralda-century21plaza-algarve-tavira-luztavira-moradia-apartamento-vender-comprar-arrendar-praia-piscina-golf_23b3efbc-aaaf-462e-b8f7-4e2d34768955.jpg',
#   'link': 2020823,
# ...
#   'link': 1979573,
#   'location': 'Portugal, Faro (Algarve), Silves (Algarve), Alcantarilha e Pera (Algarve), Barrocal (Algarve)',
#   'nbaths': '3',
#   'nrooms': '4',
#   'price': '550 000 EUR',
#   'ref': 'C0205-04182',
#   'state_prop': 'Bom',
#   'state_sale': 'Venda',
#   'type_prop': 'Moradia',
#   'usefull_area': '260'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '297',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/p1060915_9607d00e-bc29-42cf-92ce-2001216dc7b8.JPG',
#   'link': 1979979,
#   'location': 'Portugal, Vila Real, Chaves, Santa Maria Maior',
#   'nbaths': '2',
#   'nrooms': '3',
#   'price': '160 000 EUR',
#   'ref': 'C0395-00059',
#   'state_prop': 'Bom',
#   'state_sale': 'Venda',
#   'type_prop': 'Moradia',
#   'usefull_area': '285'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '182',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/p1050702_5b00bdb1-dda5-4a89-b99c-9dc8fa155f00.JPG',
#   'link': 1981403,
#   'location': 'Portugal, Braga, Povoa de Lanhoso, Povoa de Lanhoso (N. Senhora do Amparo)',
#   'nbaths': '2',
#   'nrooms': '5',
#   'price': '165 000 EUR',
#   'ref': 'C0253-00764',
#   'state_prop': 'Bom',
#   'state_sale': 'Venda',
#   'type_prop': 'Moradia',
#   'usefull_area': '300'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '881',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/lote-paint-68c810dc-aa85-4ee4-a171-5a04d4dcb557-png_915032dd-b718-4d43-be01-2ed274338698.png',
#   'link': 1982482,
#   'location': 'Portugal, Braga, Braga, Escudeiros e Penso (Santo Estevao e Sao Vicente)',
#   'nbaths': '2',
#   'nrooms': '3',
#   'price': '187 500 EUR',
#   'ref': 'C0256-01355',
#   'state_prop': 'Bom',
#   'state_sale': 'Venda',
#   'type_prop': 'Moradia',
#   'usefull_area': '219'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '625',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/72466561-469575433647888-8462261741324075008-n_7f571a48-edc8-4567-b40a-b37314d9bc9b.jpg',
#   'link': 1940281,
#   'location': 'Portugal, Braga, Barcelos, Cossourado',
#   'nbaths': '1',
#   'nrooms': '2',
#   'price': '127 000 EUR',
#   'ref': 'C0257-00603',
#   'state_prop': 'Bom',
#   'state_sale': 'Venda',
#   'type_prop': 'Moradia',
#   'usefull_area': '145'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '485',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/dsc-4998_4aa16769-fbe6-4581-8003-a0dde6a4d5ea.jpg',
#   'link': 1958712,
#   'location': 'Portugal, Lisboa, Cascais, Cascais e Estoril, Cobre',
#   'nbaths': '5',
#   'nrooms': '5',
#   'price': '720 000 EUR',
#   'ref': 'C0270-00285',
#   'state_prop': 'Bom',
#   'state_sale': 'Venda',
#   'type_prop': 'Moradia',
#   'usefull_area': '216'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '525',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/dsc-0355_eb8f6d37-15e4-46cc-b164-2c061a3dae14.JPG',
#   'link': 1961077,
#   'location': 'Portugal, Viana do Castelo, Viana do Castelo, Geraz do Lima (S.Maria S.Leocadia Moreira) Deao',
#   'nbaths': '2',
#   'nrooms': '3',
#   'price': '185 000 EUR',
#   'ref': 'C0258-01083',
#   'state_prop': 'Bom',
#   'state_sale': 'Venda',
#   'type_prop': 'Moradia',
#   'usefull_area': '125'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '378',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/moradia-anabela-fernao-ferro_8ac4020e-010c-46a3-900a-b42ba9a9bcf3.jpg',
#   'link': 1962967,
#   'location': 'Portugal, Setubal, Seixal, Fernao Ferro, Redondos',
#   'nbaths': '2',
#   'nrooms': '5',
#   'price': '210 000 EUR',
#   'ref': '0651-02832',
#   'state_prop': 'Bom',
#   'state_sale': 'Venda',
#   'type_prop': 'Moradia',
#   'usefull_area': '250'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '138',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/76177903-2379300242387510-5827428313160744960-n_f8215568-3476-4fcf-b13f-020bd541d115.jpg',
#   'link': 1967076,
#   'location': 'Portugal, Ilha de Sao Miguel (Acores), Lagoa (Acores), Agua de Pau (Acores)',
#   'nbaths': '1',
#   'nrooms': '4',
#   'price': '90 000 EUR',
#   'ref': 'C0276-01023',
#   'state_prop': 'Bom',
#   'state_sale': 'Venda',
#   'type_prop': 'Moradia',
#   'usefull_area': '90'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '387 220',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/p6160023_5fafa01b-7edf-4b1d-874f-9621f1fa975d.JPG',
#   'link': 1972127,
#   'location': 'Portugal, Faro (Algarve), Silves (Algarve), Sao Marcos da Serra (Algarve)',
#   'nbaths': '1',
#   'nrooms': '2',
#   'price': '160 000 EUR',
#   'ref': 'C0205-04176',
#   'state_prop': 'Bom',
#   'state_sale': 'Venda',
#   'type_prop': 'Moradia',
#   'usefull_area': '192'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '1 000',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/img-20191016-6360_64f10a6c-370a-4f91-83e8-bb68b366c3f5.jpg',
#   'link': 1977599,
#   'location': 'Portugal, Aveiro, Ovar, Ovar S.Joao Arada e S.Vicente de Pereira Jusa, Centro (Ovar)',
#   'nbaths': '4',
#   'nrooms': '4',
#   'price': '360 000 EUR',
#   'ref': 'C0288-00277',
#   'state_prop': 'Bom',
#   'state_sale': 'Venda',
#   'type_prop': 'Moradia',
#   'usefull_area': '288'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '127',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/31_c1b0cd72-edd7-4d77-974d-94da18a99bb3.jpg',
#   'link': 1979273,
#   'location': 'Portugal, Porto, Vila Nova de Gaia, Madalena',
#   'nbaths': '2',
#   'nrooms': '3',
#   'price': '235 000 EUR',
#   'ref': 'C0393-00056',
#   'state_prop': 'Bom',
#   'state_sale': 'Venda',
#   'type_prop': 'Moradia',
#   'usefull_area': '109'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '144',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/img-1103_b3a92083-54ab-49ce-8269-4c23f48119d2.jpg',
#   'link': 1979775,
#   'location': 'Portugal, Setubal, Sesimbra, Quinta do Conde, Conde I',
#   'nbaths': '2',
#   'nrooms': '3',
#   'price': '174 000 EUR',
#   'ref': '0651-02829',
#   'state_prop': 'Bom',
#   'state_sale': 'Venda',
#   'type_prop': 'Moradia',
#   'usefull_area': '159'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '532',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/p1010854_f983701c-8a94-44dd-b6c4-54ca9905d02c.JPG',
#   'link': 1973011,
#   'location': 'Portugal, Evora, Mora, Cabecao',
#   'nbaths': '2',
#   'nrooms': '3',
#   'price': '325 000 EUR',
#   'ref': 'C0225-02198',
#   'state_prop': 'Bom',
#   'state_sale': 'Venda',
#   'type_prop': 'Moradia',
#   'usefull_area': '158'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '132',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/img-2309_612e80f6-02d8-4d26-895d-125adbf919c4.jpg',
#   'link': 1976907,
#   'location': 'Portugal, Setubal, Seixal, Fernao Ferro, Fernao Ferro',
#   'nbaths': '1',
#   'nrooms': '3',
#   'price': '130 000 EUR',
#   'ref': 'C0242-01583',
#   'state_prop': 'Bom',
#   'state_sale': 'Vendido',
#   'type_prop': 'Moradia',
#   'usefull_area': '136'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '280',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/ja8_40f4ed86-0950-4b93-84ac-997659e6dddf.jpg',
#   'link': 1950866,
#   'location': 'Portugal, Setubal, Seixal, Corroios, Marisol',
#   'nbaths': '3',
#   'nrooms': '4',
#   'price': '360 000 EUR',
#   'ref': '0739-02162',
#   'state_prop': 'Bom',
#   'state_sale': 'Venda',
#   'type_prop': 'Moradia',
#   'usefull_area': '220'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '780',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/img-20190920-153032_8a36093e-f468-4f4a-aa0e-77f80942d82a.jpg',
#   'link': 1963224,
#   'location': 'Portugal, Aveiro, Aveiro, Requeixo Nossa Senhora de Fatima e Nariz',
#   'nbaths': '4',
#   'nrooms': '3',
#   'price': '135 000 EUR',
#   'ref': 'C0288-00276',
#   'state_prop': 'Bom',
#   'state_sale': 'Venda',
#   'type_prop': 'Moradia',
#   'usefull_area': '150'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '487',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/img-6990_5924353a-a4f3-4b42-a4c1-6ff9928a2126.jpg',
#   'link': 1970096,
#   'location': 'Portugal, Evora, Evora, Malagueira e Horta das Figueiras, Vista Alegre',
#   'nbaths': '2',
#   'nrooms': '4',
#   'price': '255 000 EUR',
#   'ref': 'C0185-02213',
#   'state_prop': 'Bom',
#   'state_sale': 'Vendido',
#   'type_prop': 'Moradia',
#   'usefull_area': '153'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '52',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/img-7092_33493963-7327-45ce-9062-2f392c8125b5.JPG',
#   'link': 1972504,
#   'location': 'Portugal, Evora, Viana do Alentejo, Alcacovas',
#   'nbaths': '1',
#   'nrooms': '2',
#   'price': '30 000 EUR',
#   'ref': 'C0185-02209',
#   'state_prop': 'Bom',
#   'state_sale': 'Venda',
#   'type_prop': 'Moradia',
#   'usefull_area': '52'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '143',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/dsc-3393_d91076db-d8c0-47ef-ae6a-84a18f68e5f6.jpg',
#   'link': 1972512,
#   'location': 'Portugal, Lisboa, Cascais, Sao Domingos de Rana, Tires',
#   'nbaths': '2',
#   'nrooms': '3',
#   'price': '349 000 EUR',
#   'ref': '1649-00880',
#   'state_prop': 'Bom',
#   'state_sale': 'Venda',
#   'type_prop': 'Moradia',
#   'usefull_area': '110'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '144',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/img-5470-li_e0e86d9a-fa69-42ec-9f78-79dd8090bdd5.jpg',
#   'link': 1972679,
#   'location': 'Portugal, Evora, Borba, Borba (Sao Bartolomeu)',
#   'nbaths': '1',
#   'nrooms': '2',
#   'price': '50 000 EUR',
#   'ref': 'C0185-02212',
#   'state_prop': 'Bom',
#   'state_sale': 'Vendido',
#   'type_prop': 'Moradia',
#   'usefull_area': '132'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '168',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/20190823-111056_c5c2c7fe-1fb6-4a7c-b60c-38346c61ac58.jpg',
#   'link': 1973016,
#   'location': 'Portugal, Porto, Povoa de Varzim, Aver-O-Mar Amorim e Terroso, Aver-O-Mar',
#   'nbaths': '3',
#   'nrooms': '3',
#   'price': '254 000 EUR',
#   'ref': 'C0251-01303',
#   'state_prop': 'Bom',
#   'state_sale': 'Venda',
#   'type_prop': 'Moradia',
#   'usefull_area': '131'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '850',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/20191025-123110_d432a71a-a581-4b68-8eef-5051688fb765.jpg',
#   'link': 1975361,
#   'location': 'Portugal, Faro (Algarve), Portimao (Algarve), Portimao (Algarve), Praia do Vau (Algarve)',
#   'nbaths': '3',
#   'nrooms': '3',
#   'price': '714 995 EUR',
#   'ref': 'C0240-01837',
#   'state_prop': 'Bom',
#   'state_sale': 'Venda',
#   'type_prop': 'Moradia',
#   'usefull_area': '182'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '264',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/73409280-961742847558480-8573870529549697024-n_6008cf14-410a-4a79-9388-373cb0832c96.jpg',
#   'link': 1976708,
#   'location': 'Portugal, Porto, Vila do Conde, Vila do Conde, Caxinas',
#   'nbaths': '2',
#   'nrooms': '5',
#   'price': '247 000 EUR',
#   'ref': 'C0251-01300',
#   'state_prop': 'Bom',
#   'state_sale': 'Vendido',
#   'type_prop': 'Moradia',
#   'usefull_area': '176'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '374',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/piscina-elevada_2d8fdb32-9575-4fe1-83fc-dc0a7306f738.jpg',
#   'link': 1977898,
#   'location': 'Portugal, Lisboa, Cascais, Carcavelos e Parede, Murtal',
#   'nbaths': '4',
#   'nrooms': '5',
#   'price': '595 000 EUR',
#   'ref': 'C0404-00029',
#   'state_prop': 'Bom',
#   'state_sale': 'Venda',
#   'type_prop': 'Moradia',
#   'usefull_area': '273'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '971',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/foto_e58c77d6-ba3c-4ede-87d0-e05d66b652c2.jpg',
#   'link': 1979490,
#   'location': 'Portugal, Lisboa, Mafra, Azueira e Sobral da Abelheira, Chanca (Sobral da Abelheira)',
#   'nbaths': '2',
#   'nrooms': '3',
#   'price': '320 000 EUR',
#   'ref': 'C0383-00110',
#   'state_prop': 'Bom',
#   'state_sale': 'Venda',
#   'type_prop': 'Moradia',
#   'usefull_area': '175'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '237',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/foto8_78038693-2c7e-4ca1-a739-dc80a329370e.jpg',
#   'link': 1979518,
#   'location': 'Portugal, Portalegre, Campo Maior, Nossa Senhora da Graca dos Degolados',
#   'nbaths': '2',
#   'nrooms': '2',
#   'price': '116 500 EUR',
#   'ref': 'C0284-00366',
#   'state_prop': 'Bom',
#   'state_sale': 'Venda',
#   'type_prop': 'Moradia',
#   'usefull_area': '150'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '750',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/c0275-00629-fts-orig-5-_0589fb11-d0be-4164-8503-69d30b67c645.PNG',
#   'link': 1980293,
#   'location': 'Portugal, Porto, Vila Nova de Gaia, Canelas',
#   'nbaths': '2',
#   'nrooms': '5',
#   'price': '210 000 EUR',
#   'ref': 'C0275-00631',
#   'state_prop': 'Bom',
#   'state_sale': 'Venda',
#   'type_prop': 'Moradia',
#   'usefull_area': '266'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '240',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/redinha-16_8cc0211d-a904-4f3b-baee-f68a51a645c6.jpg',
#   'link': 1980708,
#   'location': 'Portugal, Leiria, Pombal, Redinha',
#   'nbaths': '3',
#   'nrooms': '4',
#   'price': '85 000 EUR',
#   'ref': 'C0355-00313',
#   'state_prop': 'Bom',
#   'state_sale': 'Venda',
#   'type_prop': 'Moradia',
#   'usefull_area': '120'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '270',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/dscn9547_885ec806-49d1-49ad-85c9-574fdc6f7363.JPG',
#   'link': 1895088,
#   'location': 'Portugal, Faro (Algarve), Faro (Algarve), Faro (Se e Sao Pedro) (Algarve)',
#   'nbaths': '2',
#   'nrooms': '6',
#   'price': '370 000 EUR',
#   'ref': 'C0358-00327',
#   'state_prop': 'Bom',
#   'state_sale': 'Venda',
#   'type_prop': 'Moradia',
#   'usefull_area': '254'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '1 760',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/img-20191009-wa0003_e3728053-767f-4b78-bef0-e522820851d2.jpg',
#   'link': 1954728,
#   'location': 'Portugal, Leiria, Leiria, Arrabal',
#   'nbaths': '6',
#   'nrooms': '6',
#   'price': '795 000 EUR',
#   'ref': 'C0355-00312',
#   'state_prop': 'Bom',
#   'state_sale': 'Venda',
#   'type_prop': 'Moradia',
#   'usefull_area': '762'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '255',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/whatsapp-image-2019-10-21-at-09-48-37-2-_2aacd2ab-fd40-4bac-8798-55926ec446d3.jpg',
#   'link': 1964768,
#   'location': 'Portugal, Setubal, Sesimbra, Quinta do Conde, Pinhal do General',
#   'nbaths': '3',
#   'nrooms': '3',
#   'price': '195 000 EUR',
#   'ref': 'C0242-01582',
#   'state_prop': 'Bom',
#   'state_sale': 'Vendido',
#   'type_prop': 'Moradia',
#   'usefull_area': '220'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '1 310',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/72306059-531256097442940-237239162908966912-n_411df506-9540-4ab4-ae45-58d1c7c041e7.jpg',
#   'link': 1966089,
#   'location': 'Portugal, Braga, Esposende, Apulia e Fao, Pedrinhas (Apulia)',
#   'nbaths': '1',
#   'nrooms': '2',
#   'price': '110 000 EUR',
#   'ref': 'C0368-00113',
#   'state_prop': 'Bom',
#   'state_sale': 'Venda',
#   'type_prop': 'Moradia',
#   'usefull_area': '60'},
#  {'construction_year': 1975,
#   'energetic_cert': 'C',
#   'gross_area': '180',
#   'img_url': 'https://cdn.21onlineapp.com/assets/images/img-9384_33f8cdb0-819d-4f81-be68-367428a1701a.JPG',
#   'link': 1968791,
#   'location': 'Portugal, Leiria, Bombarral, Bombarral e Vale Covo, Centro (Bombarral)',
#   'nbaths': '2',
#   'nrooms': '3',
#   'price': '129 000 EUR',
#   'ref': 'C0183-00906',
#   'state_prop': 'Bom',
#   'state_sale': 'Venda',
#   'type_prop': 'Moradia',
#   'usefull_area': '141'},
#  ...]

# %% [markdown]
# Resumo das casas lidas

# %%
from IPython.display import HTML
from IPython.display import Image

for house in houses:
  print (house.get("title") , "," , house.get("location"), "," , house.get("price") )
  print("Detalhes-" , house.get("nbaths") , "," , house.get("nrooms") , ", Area total" ,house.get("gross_area") , ", Area util" ,house.get("useful_area") )
# Out:
# Streaming output truncated to the last 5000 lines.
# Detalhes- 1 , 3 , Area total 90 , Area util None
# None ,  Lisboa, Misericordia, Santa Catarina , 290 000 EUR
# Detalhes- 1 , 1 , Area total 69 , Area util None
# None ,  Seixal, Corroios, Santa Marta de Corroios , 118 000 EUR
# Detalhes- 2 , 2 , Area total 90 , Area util None
# None ,  Lisboa, Avenidas Novas, Parque Eduardo Vii (Sao Sebastiao da Pedreira) , 520 000 EUR
# Detalhes- 1 , 5 , Area total 148 , Area util None
# None ,  Lisboa, Campo de Ourique, Campo de Ourique (Santo Condestavel) , 225 000 EUR
# Detalhes- 1 , 2 , Area total 50 , Area util None
# None ,  Setubal, Setubal (Sao Sebastiao), Monte Belo Norte , 216 000 EUR
# Detalhes- 3 , 4 , Area total 207 , Area util None
# None ,  Almada, Caparica e Trafaria, Sao Joao da Caparica (Caparica) , 269 000 EUR
# Detalhes- 2 , 4 , Area total 170 , Area util None
# None ,  Ponta Delgada (Acores), Sao Jose (Acores) , 199 000 EUR
# Detalhes- 2 , 2 , Area total 126 , Area util None
# None ,  Porto, Bonfim , 170 000 EUR
# Detalhes- 1 , 1 , Area total 72 , Area util None
# None ,  Albufeira (Algarve), Albufeira e Olhos de Agua (Algarve), Oura (Albufeira) (Algarve) , 97 000 EUR
# Detalhes- 1 , 0 , Area total 46 , Area util None
# None ,  Silves (Algarve), Armacao de Pera (Algarve), Avenida Beira Mar (Algarve) , 750 000 EUR
# Detalhes- 4 , 3 , Area total 170 , Area util None
# None ,  Lisboa, Avenidas Novas , 690 000 EUR
# Detalhes- 4 , 6 , Area total 200 , Area util None
# None ,  Matosinhos, Custoias Leca do Balio e Guifoes, Centro (Custoias) , 95 000 EUR
# Detalhes- 2 , 2 , Area total 106 , Area util None
# None ,  Lisboa, Santa Maria Maior, Mouraria , 149 000 EUR
# Detalhes- 1 , 1 , Area total 58 , Area util None
# None ,  Leiria, Coimbrao, Praia do Pedrogao  , 98 500 EUR
# Detalhes- 2 , 3 , Area total 120 , Area util None
# None ,  Lisboa, Parque das Nacoes , 460 000 EUR
# Detalhes- 2 , 3 , Area total 145 , Area util None
# None ,  Lisboa, Parque das Nacoes , 320 000 EUR
# Detalhes- 1 , 2 , Area total 120 , Area util None
# None ,  Silves (Algarve), Armacao de Pera (Algarve), Quinta dos Arcos (Algarve) , 165 000 EUR
# Detalhes- 2 , 2 , Area total 96 , Area util None
# None ,  Montijo, Pegoes , 103 360 EUR
# Detalhes- 2 , 2 , Area total 106 , Area util None
# None ,  Figueira da Foz, Tavarede , 75 000 EUR
# Detalhes- 2 , 3 , Area total 126 , Area util None
# None ,  Sintra, Massama e Monte Abraao, Casal do Olival , 135 000 EUR
# Detalhes- 1 , 2 , Area total 119 , Area util None
# None ,  Redondo , 99 500 EUR
# Detalhes- 3 , 4 , Area total 176 , Area util None
# None ,  Oeiras, Alges Linda-A-Velha e Cruz Quebrada-Dafundo , 173 000 EUR
# Detalhes- 1 , 1 , Area total 54 , Area util None
# None ,  Funchal (Madeira), Sao Martinho (Madeira), Barreiros (Madeira) , 318 000 EUR
# Detalhes- 2 , 2 , Area total 137 , Area util None
# None ,  Nazare, Nazare, Sitio , 310 000 EUR
# Detalhes- 2 , 3 , Area total 192 , Area util None
# None ,  Vila Real de Santo Antonio (Algarve), Vila Real de Santo Antonio (Algarve) , 145 000 EUR
# Detalhes- 1 , 2 , Area total 78 , Area util None
# None ,  Lisboa, Avenidas Novas , 475 000 EUR
# Detalhes- 2 , 2 , Area total 87 , Area util None
# None ,  Borba, Borba (Sao Bartolomeu) , 65 000 EUR
# Detalhes- 2 , 3 , Area total 103 , Area util None
# None ,  Vila Vicosa, Nossa Senhora da Conceicao e Sao Bartolomeu , 80 000 EUR
# Detalhes- 2 , 4 , Area total 120 , Area util None
# None ,  Lisboa, Marvila, Bela Vista , 780 000 EUR
# Detalhes- 2 , 4 , Area total 222 , Area util None
# None ,  Machico (Madeira), Canical (Madeira) , 72 500 EUR
# Detalhes- 2 , 3 , Area total 134 , Area util None
# None ,  Lisboa, Belem, Pedroucos , 500 000 EUR
# Detalhes- 3 , 4 , Area total 157 , Area util None
# None ,  Montijo, Montijo e Afonsoeiro, Colinas do Oriente , 185 000 EUR
# Detalhes- 2 , 3 , Area total 143 , Area util None
# None ,  Vila Nova de Gaia, Mafamude e Vilar do Paraiso , 130 000 EUR
# Detalhes- 2 , 2 , Area total 116 , Area util None
# None ,  Portimao (Algarve), Boavista (Algarve) , 95 000 EUR
# Detalhes- 1 , 2 , Area total 86 , Area util None
# None ,  Entroncamento, Sao Joao Baptista, Centro , 69 500 EUR
# Detalhes- 2 , 3 , Area total 149 , Area util None
# None ,  Albufeira (Algarve), Ferreiras (Algarve), Tomilhal (Algarve) , 230 000 EUR
# Detalhes- 2 , 3 , Area total 159 , Area util None
# None ,  Porto, Bonfim, Antas , 410 000 EUR
# Detalhes- 3 , 4 , Area total 210 , Area util None
# None ,  Odivelas, Centro , 165 000 EUR
# Detalhes- 2 , 3 , Area total 94 , Area util None
# None ,  Seixal, Amora , 85 000 EUR
# Detalhes- 1 , 2 , Area total 67 , Area util None
# None ,  Montemor-O-Velho, Pereira , 115 000 EUR
# Detalhes- 2 , 3 , Area total 128 , Area util None
# None ,  Elvas, Assuncao Ajuda Salvador e Santo Ildefonso , 76 500 EUR
# Detalhes- 2 , 3 , Area total 121 , Area util None
# None ,  Santa Cruz (Madeira), Gaula (Madeira), Porto Novo (Madeira) , 185 000 EUR
# Detalhes- 2 , 2 , Area total 100 , Area util None
# None ,  Amadora, Falagueira-Venda Nova, Falagueira , 120 000 EUR
# Detalhes- 1 , 1 , Area total 55 , Area util None
# None ,  Vila Franca do Campo (Acores), Sao Miguel (Acores) , 137 500 EUR
# Detalhes- 1 , 2 , Area total 112 , Area util None
# None ,  Almada, Almada Cova da Piedade Pragal e Cacilhas, Almada , 160 000 EUR
# Detalhes- 2 , 3 , Area total 72 , Area util None
# None ,  Lisboa, Lumiar , 935 000 EUR
# Detalhes- 5 , 5 , Area total 341 , Area util None
# None ,  Viana do Castelo, Darque , 50 000 EUR
# Detalhes- 1 , 2 , Area total 100 , Area util None
# None ,  Albufeira (Algarve), Albufeira e Olhos de Agua (Algarve), Albufeira (Algarve) , 285 000 EUR
# Detalhes- 2 , 2 , Area total 128 , Area util None
# None ,  Lisboa, Misericordia, Santa Catarina , 640 000 EUR
# Detalhes- 2 , 3 , Area total 170 , Area util None
# None ,  Funchal (Madeira), Sao Martinho (Madeira), Barreiros (Madeira) , 177 900 EUR
# Detalhes- 2 , 2 , Area total 130 , Area util None
# None ,  Lisboa, Santa Maria Maior, Alfama , 295 000 EUR
# Detalhes- 2 , 2 , Area total 55 , Area util None
# None ,  Lisboa, Parque das Nacoes, Expo Norte , 480 000 EUR
# Detalhes- 1 , 2 , Area total 104 , Area util None
# None ,  Aljezur (Algarve), Odeceixe (Algarve) , 97 500 EUR
# Detalhes- 1 , 2 , Area total 47 , Area util None
# None ,  Cascais, Carcavelos e Parede, Murtal , 190 000 EUR
# Detalhes- 2 , 3 , Area total 123 , Area util None
# None ,  Soure, Granja do Ulmeiro , 91 000 EUR
# Detalhes- 2 , 3 , Area total 125 , Area util None
# None ,  Marinha Grande, Embra  , 114 000 EUR
# Detalhes- 2 , 2 , Area total 184 , Area util None
# None ,  Entroncamento, Nossa Sra de Fatima , 85 000 EUR
# Detalhes- 2 , 3 , Area total 193 , Area util None
# None ,  Lisboa, Benfica, Estrada de Benfica , 549 000 EUR
# Detalhes- 3 , 2 , Area total 175 , Area util None
# None ,  Setubal, S.Juliao N.Sao da Anunciada e S.Maria da Graca, Urbisado (Sao Juliao) , 98 000 EUR
# Detalhes- 1 , 2 , Area total 76 , Area util None
# None ,  Odivelas, Colinas do Cruzeiro , 270 000 EUR
# Detalhes- 2 , 2 , Area total 106 , Area util None
# None ,  Loures, Sacavem e Prior Velho, Prior Velho , 124 000 EUR
# Detalhes- 1 , 2 , Area total 78 , Area util None
# None ,  Sintra, Casal de Cambra , 170 000 EUR
# Detalhes- 1 , 2 , Area total 128 , Area util None
# None ,  Lisboa, Santo Antonio, Av. da Liberdade , 290 000 EUR
# Detalhes- 1 , 3 , Area total 75 , Area util None
# None ,  Lisboa, Parque das Nacoes , 350 000 EUR
# Detalhes- 1 , 3 , Area total 85 , Area util None
# None ,  Cascais, Carcavelos e Parede, Centro (Parede) , 250 000 EUR
# Detalhes- 1 , 2 , Area total 72 , Area util None
# None ,  Albufeira (Algarve), Ferreiras (Algarve), Tomilhal (Algarve) , 233 000 EUR
# Detalhes- 2 , 3 , Area total 151 , Area util None
# None ,  Oeiras, Alges Linda-A-Velha e Cruz Quebrada-Dafundo, Linda a Velha , 375 000 EUR
# Detalhes- 1 , 2 , Area total 130 , Area util None
# None ,  Nazare, Famalicao , 90 000 EUR
# Detalhes- 2 , 2 , Area total 122 , Area util None
# None ,  Lisboa, Carnide, Telheiras , 756 000 EUR
# Detalhes- 3 , 5 , Area total 240 , Area util None
# None ,  Viseu, Repeses e Sao Salvador, Sao Salvador (Sao Salvador) , 115 000 EUR
# Detalhes- 1 , 1 , Area total 70 , Area util None
# None ,  Viseu, Repeses e Sao Salvador , 145 000 EUR
# Detalhes- 2 , 2 , Area total 135 , Area util None
# None ,  Cascais, Cascais e Estoril, Bairro do Rosario , 385 000 EUR
# Detalhes- 2 , 2 , Area total 100 , Area util None
# None ,  Seixal, Seixal Arrentela e Aldeia de Paio Pires, Quinta Manuel Andre , 86 500 EUR
# Detalhes- 1 , 3 , Area total 89 , Area util None
# None ,  Cascais, Cascais e Estoril, Quinta da Bicuda , 390 000 EUR
# Detalhes- 2 , 3 , Area total 165 , Area util None
# None ,  Lisboa, Penha de Franca , 220 000 EUR
# Detalhes- 1 , 4 , Area total 93 , Area util None
# None ,  Montemor-O-Velho, Pereira, Urbanizacao S. Luis , 143 000 EUR
# Detalhes- 2 , 3 , Area total 108 , Area util None
# None ,  Montemor-O-Velho, Pereira, Urbanizacao S. Luis , 145 000 EUR
# Detalhes- 2 , 3 , Area total 108 , Area util None
# None ,  Montemor-O-Velho, Pereira, Urbanizacao S. Luis , 146 000 EUR
# Detalhes- 2 , 3 , Area total 108 , Area util None
# None ,  Montemor-O-Velho, Pereira, Urbanizacao S. Luis , 150 000 EUR
# Detalhes- 2 , 3 , Area total 108 , Area util None
# None ,  Amadora, Aguas Livres, Damaia de Baixo , 150 000 EUR
# Detalhes- 1 , 2 , Area total 90 , Area util None
# None ,  Viana do Castelo, Santa Maria Maior e Monserrate e Meadela, Argacosa (Santa Maria Maior) , 180 000 EUR
# Detalhes- 2 , 3 , Area total 129 , Area util None
# None ,  Viseu, Repeses e Sao Salvador , 155 000 EUR
# Detalhes- 2 , 2 , Area total 140 , Area util None
# None ,  Viseu, Repeses e Sao Salvador , 195 000 EUR
# Detalhes- 2 , 3 , Area total 155 , Area util None
# None ,  Viseu, Repeses e Sao Salvador , 260 000 EUR
# Detalhes- 4 , 3 , Area total 210 , Area util None
# None ,  Loule (Algarve), Quarteira (Algarve), Vilamoura (Algarve) , 189 500 EUR
# Detalhes- 1 , 1 , Area total 78 , Area util None
# None ,  Almada, Charneca de Caparica e Sobreda, Vale Fetal , 93 000 EUR
# Detalhes- 1 , 1 , Area total 63 , Area util None
# None ,  Albufeira (Algarve), Albufeira e Olhos de Agua (Algarve), Correeira (Albufeira) (Algarve) , 240 000 EUR
# Detalhes- 2 , 3 , Area total 167 , Area util None
# None ,  Lisboa, Campo de Ourique , 695 000 EUR
# Detalhes- 1 , 4 , Area total 150 , Area util None
# None ,  Seixal, Seixal Arrentela e Aldeia de Paio Pires, Paio Pires , 200 000 EUR
# Detalhes- 2 , 3 , Area total 153 , Area util None
# None ,  Braga, Real Dume e Semelhe , 92 500 EUR
# Detalhes- 3 , 3 , Area total 155 , Area util None
# None ,  Tavira (Algarve), Conceicao e Cabanas de Tavira (Algarve), Cabanas Centro (Cabanas de Tavira) (Algarve) , 97 000 EUR
# Detalhes- 1 , 1 , Area total 63 , Area util None
# None ,  Viana do Castelo, Chafe , 74 000 EUR
# Detalhes- 1 , 2 , Area total 94 , Area util None
# None ,  Albufeira (Algarve), Albufeira e Olhos de Agua (Algarve), Correeira (Albufeira) (Algarve) , 235 000 EUR
# Detalhes- 2 , 3 , Area total 160 , Area util None
# None ,  Albufeira (Algarve), Albufeira e Olhos de Agua (Algarve), A. S. Joao (Algarve) , 165 000 EUR
# Detalhes- 2 , 2 , Area total 128 , Area util None
# None ,  Silves (Algarve), Armacao de Pera (Algarve), Armacao de Pera (Algarve) , 128 000 EUR
# Detalhes- 1 , 1 , Area total 91 , Area util None
# None ,  Albufeira (Algarve), Albufeira e Olhos de Agua (Algarve), Falesia (Albufeira) (Algarve) , 135 000 EUR
# Detalhes- 1 , 1 , Area total 60 , Area util None
# None ,  Silves (Algarve), Armacao de Pera (Algarve), Quinta dos Arcos (Algarve) , 120 000 EUR
# Detalhes- 1 , 2 , Area total 80 , Area util None
# None ,  Lisboa, Lumiar , 320 000 EUR
# Detalhes- 2 , 1 , Area total 147 , Area util None
# None ,  Lagos (Algarve), Lagos (Sao Sebastiao e Santa Maria) (Algarve) , 305 000 EUR
# Detalhes- 2 , 2 , Area total 112 , Area util None
# None ,  Loule (Algarve), Quarteira (Algarve), Av. Sa Carneiro (Algarve) , 190 000 EUR
# Detalhes- 2 , 3 , Area total 86 , Area util None
# None ,  Sintra, S.Maria e S.Miguel S.Martinho S.Pedro Penaferrim, Quinta da Beloura (Sao Pedro Penaferrim) , 355 000 EUR
# Detalhes- 1 , 2 , Area total 148 , Area util None
# None ,  Lisboa, Marvila , 198 000 EUR
# Detalhes- 1 , 3 , Area total 73 , Area util None
# None ,  Vila Nova de Gaia, Santa Marinha e Sao Pedro da Afurada, Devesas (Santa Marinha) , 89 900 EUR
# Detalhes- 1 , 2 , Area total 88 , Area util None
# None ,  Santarem, Romeira e Varzea, Centro (Romeira) , 49 900 EUR
# Detalhes- 1 , 1 , Area total 51 , Area util None
# None ,  Paredes, Louredo , 80 000 EUR
# Detalhes- 2 , 2 , Area total 137 , Area util None
# None ,  Loures, Sacavem e Prior Velho, Sacavem , 140 000 EUR
# Detalhes- 1 , 2 , Area total 70 , Area util None
# None ,  Albufeira (Algarve), Guia (Algarve), Salgados (Algarve) , 114 000 EUR
# Detalhes- 1 , 1 , Area total 59 , Area util None
# None ,  Amadora, Venteira, Serra de Carnaxide (Venteira) , 261 000 EUR
# Detalhes- 2 , 3 , Area total 144 , Area util None
# None ,  Setubal, Setubal (Sao Sebastiao), Lanchoa , 59 000 EUR
# Detalhes- 1 , 2 , Area total 65 , Area util None
# None ,  Figueira da Foz, Buarcos(Bairro Novo) , 145 000 EUR
# Detalhes- 2 , 4 , Area total 228 , Area util None
# None ,  Lisboa, Santa Maria Maior , 197 500 EUR
# Detalhes- 1 , 2 , Area total 75 , Area util None
# None ,  Matosinhos, Matosinhos e Leca da Palmeira, Centro (Matosinhos) , 130 000 EUR
# Detalhes- 1 , 1 , Area total 39 , Area util None
# None ,  Funchal (Madeira), Sao Martinho (Madeira), Nazare (Madeira) , 650 000 EUR
# Detalhes- 4 , 4 , Area total 307 , Area util None
# None ,  Faro (Algarve), Faro (Se e Sao Pedro) (Algarve), Alto Rodes (Se) (Algarve) , 151 500 EUR
# Detalhes- 2 , 3 , Area total 127 , Area util None
# None ,  Lisboa, Misericordia, Bairro Alto , 295 000 EUR
# Detalhes- 1 , 1 , Area total 75 , Area util None
# None ,  Ourem, Nossa Senhora da Piedade , 130 000 EUR
# Detalhes- 2 , 3 , Area total 96 , Area util None
# None ,  Albufeira (Algarve), Albufeira e Olhos de Agua (Algarve), Sesmarias (Albufeira) (Algarve) , 175 000 EUR
# Detalhes- 2 , 2 , Area total 112 , Area util None
# None ,  Alcobaca, Coz Alpedriz e Montes , 72 500 EUR
# Detalhes- 2 , 3 , Area total 112 , Area util None
# None ,  Amadora, Aguas Livres, Atalaia , 305 000 EUR
# Detalhes- 2 , 3 , Area total 160 , Area util None
# None ,  Lisboa, Benfica, Colegio Militar , 525 000 EUR
# Detalhes- 2 , 3 , Area total 136 , Area util None
# None ,  Montijo, Montijo e Afonsoeiro, Colinas do Oriente , 139 000 EUR
# Detalhes- 2 , 3 , Area total 179 , Area util None
# None ,  Barcelos, Arcozelo , 90 500 EUR
# Detalhes- 2 , 3 , Area total 115 , Area util None
# None ,  Braga, Braga (Maximinos Se e Cividade) , 201 500 EUR
# Detalhes- 3 , 3 , Area total 173 , Area util None
# None ,  Alcobaca, Pataias e Martinganca, Pedra do Ouro , 198 500 EUR
# Detalhes- 2 , 3 , Area total 180 , Area util None
# None ,  Braga, Nogueiro e Tenoes , 320 000 EUR
# Detalhes- 5 , 5 , Area total 335 , Area util None
# None ,  Sintra, Algueirao-Mem Martins, Bairro da Nova Imagem , 71 200 EUR
# Detalhes- 1 , 2 , Area total 76 , Area util None
# None ,  Lisboa, Santo Antonio, Av. da Liberdade , 420 000 EUR
# Detalhes- 2 , 3 , Area total 100 , Area util None
# None ,  Seixal, Seixal Arrentela e Aldeia de Paio Pires, Paio Pires , 92 500 EUR
# Detalhes- 1 , 2 , Area total 107 , Area util None
# None ,  Silves (Algarve), Armacao de Pera (Algarve), Avenida Beira Mar (Algarve) , 145 000 EUR
# Detalhes- 1 , 2 , Area total 86 , Area util None
# None ,  Vila do Conde, Centro , 180 000 EUR
# Detalhes- 2 , 2 , Area total 148 , Area util None
# None ,  Odivelas, Colinas do Cruzeiro , 530 000 EUR
# Detalhes- 3 , 4 , Area total 160 , Area util None
# None ,  Almada, Almada Cova da Piedade Pragal e Cacilhas, Almada Velha , 105 000 EUR
# Detalhes- 1 , 2 , Area total 80 , Area util None
# None ,  Viana do Castelo, Chafe , 75 000 EUR
# Detalhes- 1 , 2 , Area total 78 , Area util None
# None ,  Leiria, Marrazes e Barosa, Vale da Fonte , 135 000 EUR
# Detalhes- 2 , 3 , Area total 150 , Area util None
# None ,  Faro (Algarve), Faro (Se e Sao Pedro) (Algarve), Centro (Se) (Algarve) , 220 000 EUR
# Detalhes- 1 , 2 , Area total 127 , Area util None
# None ,  Funchal (Madeira), Se (Madeira), Ilheus (Madeira) , 770 000 EUR
# Detalhes- 4 , 3 , Area total 230 , Area util None
# None ,  Braga, Nogueira Fraiao e Lamacaes, Falperra (Nogueira) , 89 500 EUR
# Detalhes- 1 , 2 , Area total 88 , Area util None
# None ,  Amadora, Encosta do Sol, Colina do Sol (Alfornelos) , 195 000 EUR
# Detalhes- 1 , 2 , Area total 80 , Area util None
# None ,  Viseu, Repeses e Sao Salvador , 142 500 EUR
# Detalhes- 2 , 2 , Area total 116 , Area util None
# None ,  Viseu, Repeses e Sao Salvador , 172 500 EUR
# Detalhes- 3 , 3 , Area total 145 , Area util None
# None ,  Santo Tirso, Aves , 139 000 EUR
# Detalhes- 2 , 4 , Area total 148 , Area util None
# None ,  Loule (Algarve), Quarteira (Algarve) , 267 500 EUR
# Detalhes- 2 , 2 , Area total 108 , Area util None
# None ,  Caminha, Vila Praia de Ancora , 110 000 EUR
# Detalhes- 2 , 3 , Area total 150 , Area util None
# None ,  Loule (Algarve), Loule (Sao Clemente) (Algarve), Centro (Algarve) , 115 000 EUR
# Detalhes- 2 , 3 , Area total 94 , Area util None
# None ,  Seixal, Corroios, Vale Milhacos , 170 000 EUR
# Detalhes- 1 , 2 , Area total 80 , Area util None
# None ,  Lisboa, Penha de Franca, Alto de Sao Joao , 239 000 EUR
# Detalhes- 1 , 2 , Area total 75 , Area util None
# None ,  Santa Cruz (Madeira), Canico (Madeira), Centro (Madeira) , 100 000 EUR
# Detalhes- 2 , 2 , Area total 95 , Area util None
# None ,  Seixal, Corroios, Vale Milhacos , 192 500 EUR
# Detalhes- 2 , 3 , Area total 100 , Area util None
# None ,  Lisboa, Misericordia, Sao Paulo , 400 000 EUR
# Detalhes- 1 , 3 , Area total 143 , Area util None
# None ,  Tavira (Algarve), Tavira (Santa Maria e Santiago) (Algarve), Santiago (Santiago Tavira) (Algarve) , 228 000 EUR
# Detalhes- 2 , 3 , Area total 142 , Area util None
# None ,  Agueda, Agueda e Borralha, Centro (Agueda) , 90 000 EUR
# Detalhes- 2 , 3 , Area total 149 , Area util None
# None ,  Lagos (Algarve), Lagos (Sao Sebastiao e Santa Maria) (Algarve), Porto de Mos (Santa Maria) (Algarve) , 325 000 EUR
# Detalhes- 2 , 2 , Area total 134 , Area util None
# None ,  Lagos (Algarve), Lagos (Sao Sebastiao e Santa Maria) (Algarve), Centro (Sao Sebastiao) (Algarve) , 405 000 EUR
# Detalhes- 2 , 2 , Area total 157 , Area util None
# None ,  Lagos (Algarve), Lagos (Sao Sebastiao e Santa Maria) (Algarve), Centro (Sao Sebastiao) (Algarve) , 335 000 EUR
# Detalhes- 2 , 2 , Area total 148 , Area util None
# None ,  Funchal (Madeira), Sao Martinho (Madeira), Virtudes (Madeira) , 225 000 EUR
# Detalhes- 2 , 2 , Area total 117 , Area util None
# None ,  Funchal (Madeira), Sao Martinho (Madeira), Virtudes (Madeira) , 335 000 EUR
# Detalhes- 2 , 3 , Area total 180 , Area util None
# None ,  Funchal (Madeira), Sao Martinho (Madeira), Virtudes (Madeira) , 195 000 EUR
# Detalhes- 1 , 1 , Area total 91 , Area util None
# None ,  Barreiro, Santo Antonio da Charneca, Cidade Sol , 74 500 EUR
# Detalhes- 2 , 3 , Area total 86 , Area util None
# None ,  Alenquer, Aldeia Galega da Merceana e Aldeia Gavinha , 69 900 EUR
# Detalhes- 1 , 2 , Area total 128 , Area util None
# None ,  Nazare, Nazare, Sitio , 160 000 EUR
# Detalhes- 1 , 2 , Area total 80 , Area util None
# None ,  Viana do Castelo, Darque , 76 000 EUR
# Detalhes- 2 , 3 , Area total 124 , Area util None
# None ,  Portimao (Algarve), Alto do Quintao (Algarve) , 145 000 EUR
# Detalhes- 2 , 3 , Area total 130 , Area util None
# None ,  Lisboa, Estrela, Santos (Santos-O-Velho) , 200 000 EUR
# Detalhes- 1 , 1 , Area total 50 , Area util None
# None ,  Funchal (Madeira), Sao Martinho (Madeira), Piornais (Madeira) , 158 000 EUR
# Detalhes- 1 , 1 , Area total 79 , Area util None
# None ,  Vila Nova de Gaia, Canidelo , 289 900 EUR
# Detalhes- 2 , 2 , Area total 107 , Area util None
# None ,  Almada, Caparica e Trafaria, Monte da Caparica , 98 650 EUR
# Detalhes- 1 , 2 , Area total 71 , Area util None
# None ,  Nazare, Nazare, Nazare , 290 000 EUR
# Detalhes- 2 , 3 , Area total 170 , Area util None
# None ,  Funchal (Madeira), Sao Martinho (Madeira), Piornais (Madeira) , 195 000 EUR
# Detalhes- 2 , 2 , Area total 129 , Area util None
# None ,  Sintra, Massama e Monte Abraao, Massama Norte , 375 000 EUR
# Detalhes- 3 , 3 , Area total 146 , Area util None
# None ,  Funchal (Madeira), Santa Maria Maior (Madeira), Centro (Madeira) , 245 000 EUR
# Detalhes- 2 , 2 , Area total 158 , Area util None
# None ,  Viana do Castelo, Areosa , 90 000 EUR
# Detalhes- 2 , 3 , Area total 107 , Area util None
# None ,  Coimbra, Sao Martinho do Bispo e Ribeira de Frades, Fala , 83 500 EUR
# Detalhes- 2 , 3 , Area total 114 , Area util None
# None ,  Leiria, Parceiros e Azoia, Santa Clara (Parceiros) , 240 000 EUR
# Detalhes- 3 , 3 , Area total 249 , Area util None
# None ,  Lisboa, Arroios, Arroios (Sao Jorge de Arroios) , 285 000 EUR
# Detalhes- 2 , 2 , Area total 69 , Area util None
# None ,  Lisboa, Sao Domingos de Benfica , 440 000 EUR
# Detalhes- 2 , 4 , Area total 170 , Area util None
# None ,  Paredes, Casteloes de Cepeda , 53 000 EUR
# Detalhes- 1 , 2 , Area total 60 , Area util None
# None ,  Almada, Laranjeiro e Feijo, Laranjeiro , 91 150 EUR
# Detalhes- 2 , 3 , Area total 92 , Area util None
# None ,  Nazare, Nazare, Camarcao , 117 500 EUR
# Detalhes- 2 , 2 , Area total 93 , Area util None
# None ,  Albufeira (Algarve), Albufeira e Olhos de Agua (Algarve), Oura (Albufeira) (Algarve) , 109 000 EUR
# Detalhes- 1 , 1 , Area total 59 , Area util None
# None ,  Vila Franca de Xira, Alhandra Sao Joao dos Montes e Calhandriz, Alhandra , 215 000 EUR
# Detalhes- 3 , 3 , Area total 224 , Area util None
# None ,  Lisboa, Sao Vicente, Santa Engracia , 95 000 EUR
# Detalhes- 1 , 0 , Area total 35 , Area util None
# None ,  Sintra, Queluz e Belas, Queluz , 125 000 EUR
# Detalhes- 2 , 3 , Area total 160 , Area util None
# None ,  Olhao (Algarve), Baixa (Algarve) , 184 000 EUR
# Detalhes- 2 , 1 , Area total 104 , Area util None
# None ,  Lisboa, Estrela , 495 000 EUR
# Detalhes- 2 , 3 , Area total 150 , Area util None
# None ,  Paredes, Baltar , 98 500 EUR
# Detalhes- 2 , 3 , Area total 113 , Area util None
# None ,  Lisboa, Santa Maria Maior, Socorro , 245 000 EUR
# Detalhes- 1 , 3 , Area total 80 , Area util None
# None ,  Cascais, Cascais e Estoril , 175 000 EUR
# Detalhes- 1 , 1 , Area total 67 , Area util None
# None ,  Tavira (Algarve), Santa Luzia (Algarve) , 175 000 EUR
# Detalhes- 1 , 2 , Area total 94 , Area util None
# None ,  Lisboa, Belem, Belem (Santa Maria de Belem) , 470 000 EUR
# Detalhes- 2 , 3 , Area total 170 , Area util None
# None ,  Porto, Ramalde, Carvalhido , 220 000 EUR
# Detalhes- 2 , 3 , Area total 151 , Area util None
# None ,  Lisboa, Alcantara, Alcantara , 152 500 EUR
# Detalhes- 1 , 1 , Area total 44 , Area util None
# None ,  Viseu , 155 000 EUR
# Detalhes- 2 , 2 , Area total 124 , Area util None
# None ,  Viseu , 187 000 EUR
# Detalhes- 3 , 3 , Area total 150 , Area util None
# None ,  Entroncamento, Sao Joao Baptista , 100 000 EUR
# Detalhes- 2 , 2 , Area total 141 , Area util None
# None ,  Oliveira do Bairro , 67 000 EUR
# Detalhes- 1 , 2 , Area total 75 , Area util None
# None ,  Viseu , 290 000 EUR
# Detalhes- 4 , 4 , Area total 204 , Area util None
# None ,  Vila Franca de Xira, Vialonga , 115 000 EUR
# Detalhes- 1 , 1 , Area total 92 , Area util None
# None ,  Vila Franca de Xira, Vialonga , 115 000 EUR
# Detalhes- 1 , 1 , Area total 92 , Area util None
# None ,  Tavira (Algarve), Tavira (Santa Maria e Santiago) (Algarve), Santiago (Santiago Tavira) (Algarve) , 248 000 EUR
# Detalhes- 2 , 2 , Area total 97 , Area util None
# None ,  Tavira (Algarve), Tavira (Santa Maria e Santiago) (Algarve) , 246 100 EUR
# Detalhes- 2 , 2 , Area total 99 , Area util None
# None ,  Albufeira (Algarve), Albufeira e Olhos de Agua (Algarve), Areias de Sao Joao (Albufeira) (Algarve) , 172 500 EUR
# Detalhes- 2 , 1 , Area total 83 , Area util None
# None ,  Lisboa, Arroios, Sao Jorge de Arroios , 350 000 EUR
# Detalhes- 1 , 4 , Area total 136 , Area util None
# None ,  Marinha Grande, Vieira de Leiria, Praia da Vieira de Leiria , 202 450 EUR
# Detalhes- 1 , 2 , Area total 133 , Area util None
# None ,  Lisboa, Belem, Pedroucos , 285 000 EUR
# Detalhes- 2 , 2 , Area total 90 , Area util None
# None ,  Loule (Algarve), Quarteira (Algarve) , 294 400 EUR
# Detalhes- 1 , 2 , Area total 129 , Area util None
# None ,  Loule (Algarve), Quarteira (Algarve) , 294 400 EUR
# Detalhes- 1 , 2 , Area total 129 , Area util None
# None ,  Loule (Algarve), Quarteira (Algarve) , 294 500 EUR
# Detalhes- 1 , 2 , Area total 137 , Area util None
# None ,  Loule (Algarve), Quarteira (Algarve) , 294 500 EUR
# Detalhes- 1 , 2 , Area total 137 , Area util None
# None ,  Palmela, Quinta do Anjo, Colinas da Arrabida , 110 000 EUR
# Detalhes- 2 , 2 , Area total 130 , Area util None
# None ,  Lisboa, Santa Maria Maior, Sao Paulo , 900 000 EUR
# Detalhes- 3 , 3 , Area total 186 , Area util None
# None ,  Moita, Baixa da Banheira e Vale da Amoreira, Bxa da Banheira-Centro , 24 000 EUR
# Detalhes- 1 , 1 , Area total 53 , Area util None
# None ,  Lisboa, Alcantara, Alcantara , 450 000 EUR
# Detalhes- 2 , 2 , Area total 95 , Area util None
# None ,  Seixal, Corroios, Miratejo , 56 000 EUR
# Detalhes- 1 , 1 , Area total 37 , Area util None
# None ,  Albufeira (Algarve), Albufeira e Olhos de Agua (Algarve), Baixa de Albufeira (Algarve) , 350 000 EUR
# Detalhes- 2 , 3 , Area total 151 , Area util None
# None ,  Alcochete, Sao Francisco , 350 000 EUR
# Detalhes- 2 , 3 , Area total 185 , Area util None
# None ,  Seixal, Corroios, Quinta do Rouxinol , 99 000 EUR
# Detalhes- 2 , 3 , Area total 108 , Area util None
# None ,  Silves (Algarve), Algoz e Tunes (Algarve), Centro (Algarve) , 150 000 EUR
# Detalhes- 1 , 2 , Area total 104 , Area util None
# None ,  Lisboa, Santa Maria Maior, Alfama , 330 000 EUR
# Detalhes- 1 , 2 , Area total 126 , Area util None
# None ,  Lisboa, Santo Antonio, Capuchos , 387 000 EUR
# Detalhes- 1 , 3 , Area total 125 , Area util None
# None ,  Lagoa (Algarve), Estombar e Parchal (Algarve), Estombar (Algarve) , 235 000 EUR
# Detalhes- 1 , 1 , Area total 82 , Area util None
# None ,  Santa Cruz (Madeira), Canico (Madeira), Canico Centro (Madeira) , 122 500 EUR
# Detalhes- 2 , 2 , Area total 107 , Area util None
# None ,  Sintra, Massama e Monte Abraao, Massama Norte , 295 000 EUR
# Detalhes- 3 , 4 , Area total 147 , Area util None
# None ,  Entroncamento, Sao Joao Baptista , 63 000 EUR
# Detalhes- 2 , 3 , Area total 141 , Area util None
# None ,  Lisboa, Penha de Franca , 249 000 EUR
# Detalhes- 2 , 2 , Area total 51 , Area util None
# None ,  Lousa, Lousa e Vilarinho, Vila da Lousa (Lousa) , 85 000 EUR
# Detalhes- 1 , 2 , Area total 92 , Area util None
# None ,  Evora, Evora (Sao Mamede Se Sao Pedro e Santo Antao), Centro Historico , 390 000 EUR
# Detalhes- 4 , 10 , Area total 588 , Area util None
# None ,  Santa Cruz (Madeira), Canico (Madeira), Barreiros (Madeira) , 89 000 EUR
# Detalhes- 1 , 1 , Area total 99 , Area util None
# None ,  Braga, Sao Vitor , 139 500 EUR
# Detalhes- 2 , 2 , Area total 140 , Area util None
# None ,  Sintra, Agualva e Mira-Sintra , 85 000 EUR
# Detalhes- 1 , 2 , Area total 60 , Area util None
# None ,  Montijo, Montijo e Afonsoeiro, Vale Salgueiro , 150 000 EUR
# Detalhes- 1 , 2 , Area total 118 , Area util None
# None ,  Sintra, Algueirao-Mem Martins, Mem Martins , 130 000 EUR
# Detalhes- 2 , 3 , Area total 112 , Area util None
# None ,  Marinha Grande, Vieira de Leiria, Praia da Vieira de Leiria , 95 000 EUR
# Detalhes- 1 , 2 , Area total 121 , Area util None
# None ,  Lagoa (Acores), Agua de Pau (Acores) , 100 000 EUR
# Detalhes- 1 , 3 , Area total 99 , Area util None
# None ,  Moita, Alhos Vedros, Alhos Vedros-Urb. Vila Verde , 105 500 EUR
# Detalhes- 2 , 3 , Area total 108 , Area util None
# None ,  Santa Cruz (Madeira), Canico (Madeira), Assomada (Madeira) , 85 000 EUR
# Detalhes- 2 , 2 , Area total 87 , Area util None
# None ,  Seixal, Seixal Arrentela e Aldeia de Paio Pires, Paio Pires , 72 900 EUR
# Detalhes- 1 , 2 , Area total 83 , Area util None
# None ,  Beja, Beja (Salvador e Santa Maria da Feira), Centro (Santa Maria da Feira) , 76 500 EUR
# Detalhes- 1 , 2 , Area total 100 , Area util None
# None ,  Entroncamento, Sao Joao Baptista , 75 000 EUR
# Detalhes- 3 , 3 , Area total 141 , Area util None
# None ,  Lisboa, Parque das Nacoes , 415 000 EUR
# Detalhes- 1 , 2 , Area total 120 , Area util None
# None ,  Setubal, S.Juliao N.Sao da Anunciada e S.Maria da Graca, Palhava , 120 000 EUR
# Detalhes- 2 , 2 , Area total 102 , Area util None
# None ,  Ponta Delgada (Acores), Rosto de Cao (Sao Roque) (Acores) , 105 000 EUR
# Detalhes- 1 , 1 , Area total 81 , Area util None
# None ,  Lisboa, Misericordia, Sao Bento , 300 000 EUR
# Detalhes- 2 , 2 , Area total 58 , Area util None
# None ,  Lisboa, Arroios, Morais Soares , 549 000 EUR
# Detalhes- 2 , 3 , Area total 110 , Area util None
# None ,  Lisboa, Avenidas Novas, Av. 5 de Outubro , 469 000 EUR
# Detalhes- 2 , 2 , Area total 80 , Area util None
# None ,  Loule (Algarve), Quarteira (Algarve), Vilamoura (Algarve) , 320 000 EUR
# Detalhes- 2 , 2 , Area total 124 , Area util None
# None ,  Viseu, Ranhados , 157 500 EUR
# Detalhes- 2 , 2 , Area total 130 , Area util None
# None ,  Porto de Mos, Mira de Aire, Centro , 82 000 EUR
# Detalhes- 2 , 4 , Area total 213 , Area util None
# None ,  Almada, Almada Cova da Piedade Pragal e Cacilhas, Almada , 134 500 EUR
# Detalhes- 1 , 2 , Area total 70 , Area util None
# None ,  Almada, Almada Cova da Piedade Pragal e Cacilhas, Almada , 92 000 EUR
# Detalhes- 1 , 0 , Area total 44 , Area util None
# None ,  Funchal (Madeira), Sao Martinho (Madeira), Casa Branca (Madeira) , 310 000 EUR
# Detalhes- 2 , 1 , Area total 109 , Area util None
# None ,  Funchal (Madeira), Sao Martinho (Madeira), Casa Branca (Madeira) , 405 000 EUR
# Detalhes- 2 , 2 , Area total 144 , Area util None
# None ,  Funchal (Madeira), Sao Martinho (Madeira), Casa Branca (Madeira) , 535 000 EUR
# Detalhes- 4 , 3 , Area total 187 , Area util None
# None ,  Funchal (Madeira), Sao Martinho (Madeira), Casa Branca (Madeira) , 710 000 EUR
# Detalhes- 5 , 4 , Area total 277 , Area util None
# None ,  Lisboa, Avenidas Novas, Campo Pequeno , 1 200 000 EUR
# Detalhes- 3 , 5 , Area total 240 , Area util None
# None ,  Lagoa (Algarve), Porches (Algarve) , 215 000 EUR
# Detalhes- 2 , 2 , Area total 125 , Area util None
# None ,  Santarem, Marvila Ribeira Santarem S.Salvador S.Nicolau, Fontainhas , 75 000 EUR
# Detalhes- 2 , 2 , Area total 93 , Area util None
# None ,  Sintra, Rio de Mouro, Asfamil , 250 000 EUR
# Detalhes- 2 , 2 , Area total 95 , Area util None
# None ,  Lagoa (Acores), Santa Cruz (Acores) , 98 500 EUR
# Detalhes- 1 , 2 , Area total 72 , Area util None
# None ,  Seixal, Corroios, Santa Marta do Pinhal , 73 500 EUR
# Detalhes- 1 , 1 , Area total 58 , Area util None
# None ,  Montijo, Montijo e Afonsoeiro, Montijo Residence , 140 000 EUR
# Detalhes- 3 , 5 , Area total 194 , Area util None
# None ,  Santarem, Marvila Ribeira Santarem S.Salvador S.Nicolau, Zona Historica (Marvila) , 185 000 EUR
# Detalhes- 3 , 3 , Area total 141 , Area util None
# None ,  Viseu , 220 000 EUR
# Detalhes- 2 , 3 , Area total 191 , Area util None
# None ,  Viseu , 145 000 EUR
# Detalhes- 2 , 2 , Area total 159 , Area util None
# None ,  Santa Cruz (Madeira), Canico (Madeira), Eiras (Madeira) , 92 000 EUR
# Detalhes- 1 , 2 , Area total 93 , Area util None
# None ,  Miranda do Corvo, Vila de Miranda , 36 000 EUR
# Detalhes- 1 , 2 , Area total 85 , Area util None
# None ,  Lisboa, Lumiar , 380 000 EUR
# Detalhes- 1 , 1 , Area total 133 , Area util None
# None ,  Sintra, Rio de Mouro, Fitares (Rio de Mouro) , 85 000 EUR
# Detalhes- 1 , 2 , Area total 93 , Area util None
# None ,  Seixal, Seixal Arrentela e Aldeia de Paio Pires, Torre da Marinha , 90 000 EUR
# Detalhes- 1 , 1 , Area total 75 , Area util None
# None ,  Loule (Algarve), Quarteira (Algarve), Vilamoura (Algarve) , 255 000 EUR
# Detalhes- 1 , 1 , Area total 90 , Area util None
# None ,  Silves (Algarve), Armacao de Pera (Algarve), Avenida Beira Mar (Algarve) , 190 000 EUR
# Detalhes- 1 , 2 , Area total 161 , Area util None
# None ,  Pombal, Guia Ilha e Mata Mourisca , 112 000 EUR
# Detalhes- 1 , 2 , Area total 114 , Area util None
# None ,  Esposende, Esposende Marinhas e Gandra , 91 000 EUR
# Detalhes- 1 , 2 , Area total 60 , Area util None
# None ,  Cascais, Cascais e Estoril, Guia , 345 000 EUR
# Detalhes- 2 , 2 , Area total 107 , Area util None
# None ,  Esposende, Esposende Marinhas e Gandra , 77 000 EUR
# Detalhes- 1 , 1 , Area total 51 , Area util None
# None ,  Albufeira (Algarve), Albufeira e Olhos de Agua (Algarve), Montechoro (Albufeira) (Algarve) , 79 900 EUR
# Detalhes- 2 , 1 , Area total 69 , Area util None
# None ,  Santarem, Marvila Ribeira Santarem S.Salvador S.Nicolau, Calcada do Monte (Sao Salvador) , 56 000 EUR
# Detalhes- 1 , 1 , Area total 65 , Area util None
# None ,  Amadora, Mina de Agua , 126 000 EUR
# Detalhes- 1 , 2 , Area total 76 , Area util None
# None ,  Silves (Algarve), Armacao de Pera (Algarve), Avenida Beira Mar (Algarve) , 160 000 EUR
# Detalhes- 1 , 2 , Area total 98 , Area util None
# None ,  Loule (Algarve), Quarteira (Algarve) , 240 000 EUR
# Detalhes- 2 , 2 , Area total 200 , Area util None
# None ,  Loule (Algarve), Quarteira (Algarve) , 260 000 EUR
# Detalhes- 2 , 2 , Area total 270 , Area util None
# None ,  Loule (Algarve), Quarteira (Algarve) , 320 000 EUR
# Detalhes- 2 , 3 , Area total 240 , Area util None
# None ,  Loule (Algarve), Quarteira (Algarve) , 320 000 EUR
# Detalhes- 2 , 3 , Area total 189 , Area util None
# None ,  Loule (Algarve), Quarteira (Algarve) , 360 000 EUR
# Detalhes- 3 , 4 , Area total 160 , Area util None
# None ,  Loule (Algarve), Quarteira (Algarve) , 310 000 EUR
# Detalhes- 2 , 3 , Area total 137 , Area util None
# None ,  Loule (Algarve), Quarteira (Algarve) , 250 000 EUR
# Detalhes- 2 , 3 , Area total 150 , Area util None
# None ,  Loule (Algarve), Quarteira (Algarve) , 260 000 EUR
# Detalhes- 2 , 2 , Area total 270 , Area util None
# None ,  Oeiras, Alges Linda-A-Velha e Cruz Quebrada-Dafundo, Alto do Dafundo , 160 000 EUR
# Detalhes- 1 , 1 , Area total 55 , Area util None
# None ,  Albufeira (Algarve), Albufeira e Olhos de Agua (Algarve), Cerro Alagoa (Albufeira) (Algarve) , 160 000 EUR
# Detalhes- 1 , 1 , Area total 59 , Area util None
# None ,  Macao, Envendos , 109 000 EUR
# Detalhes- 2 , 2 , Area total 123 , Area util None
# None ,  Albufeira (Algarve), Albufeira e Olhos de Agua (Algarve), Areias de Sao Joao (Albufeira) (Algarve) , 230 000 EUR
# Detalhes- 2 , 2 , Area total 145 , Area util None
# None ,  Santarem, Pernes, Centro , 70 000 EUR
# Detalhes- 1 , 2 , Area total 111 , Area util None
# None ,  Almada, Almada Cova da Piedade Pragal e Cacilhas, Almada , 99 000 EUR
# Detalhes- 1 , 1 , Area total 94 , Area util None
# None ,  Povoa de Varzim, Povoa de Varzim Beiriz e Argivai, Matriz (Povoa de Varzim) , 78 500 EUR
# Detalhes- 1 , 2 , Area total 70 , Area util None
# None ,  Silves (Algarve), Armacao de Pera (Algarve), Panasqueira (Algarve) , 250 000 EUR
# Detalhes- 2 , 2 , Area total 125 , Area util None
# None ,  Silves (Algarve), Armacao de Pera (Algarve), Panasqueira (Algarve) , 155 000 EUR
# Detalhes- 2 , 1 , Area total 68 , Area util None
# None ,  Vila Nova de Gaia, Santa Marinha e Sao Pedro da Afurada , 96 000 EUR
# Detalhes- 2 , 2 , Area total 109 , Area util None
# None ,  Cascais, Alcabideche, Alvide , 435 000 EUR
# Detalhes- 3 , 3 , Area total 450 , Area util None
# None ,  Paredes, Aguiar de Sousa , 78 000 EUR
# Detalhes- 2 , 2 , Area total 124 , Area util None
# None ,  Albufeira (Algarve), Albufeira e Olhos de Agua (Algarve), Oura (Albufeira) (Algarve) , 109 900 EUR
# Detalhes- 1 , 1 , Area total 67 , Area util None
# None ,  Lisboa, Lumiar, Parque das Conchas , 1 650 000 EUR
# Detalhes- 5 , 6 , Area total 359 , Area util None
# None ,  Alenquer, Carregado e Cadafais, Centro (Carregado) , 49 000 EUR
# Detalhes- 1 , 2 , Area total 77 , Area util None
# None ,  Vila Franca de Xira, Vialonga , 78 000 EUR
# Detalhes- 1 , 1 , Area total 65 , Area util None
# None ,  Almada, Laranjeiro e Feijo, Feijo  , 126 000 EUR
# Detalhes- 2 , 3 , Area total 115 , Area util None
# None ,  Povoa de Varzim, Povoa de Varzim Beiriz e Argivai , 97 000 EUR
# Detalhes- 1 , 1 , Area total 50 , Area util None
# None ,  Seixal, Seixal Arrentela e Aldeia de Paio Pires, Arrentela (Arrentela) , 84 500 EUR
# Detalhes- 1 , 2 , Area total 78 , Area util None
# None ,  Alcobaca, Aljubarrota , 83 000 EUR
# Detalhes- 2 , 3 , Area total 141 , Area util None
# None ,  Entroncamento, Nossa Sra de Fatima , 65 500 EUR
# Detalhes- 2 , 3 , Area total 139 , Area util None
# None ,  Funchal (Madeira), Sao Martinho (Madeira), Piornais (Madeira) , 255 000 EUR
# Detalhes- 2 , 2 , Area total 129 , Area util None
# None ,  Funchal (Madeira), Sao Martinho (Madeira), Piornais (Madeira) , 245 000 EUR
# Detalhes- 2 , 2 , Area total 127 , Area util None
# None ,  Albufeira (Algarve), Albufeira e Olhos de Agua (Algarve), Orada (Albufeira) (Algarve) , 220 000 EUR
# Detalhes- 2 , 2 , Area total 105 , Area util None
# None ,  Loule (Algarve), Quarteira (Algarve) , 180 000 EUR
# Detalhes- 1 , 1 , Area total 75 , Area util None
# None ,  Elvas, Assuncao Ajuda Salvador e Santo Ildefonso , 110 000 EUR
# Detalhes- 2 , 3 , Area total 115 , Area util None
# None ,  Montemor-O-Novo, N. Sra. da Vila, N. Sra. do Bispo e Silveiras , 79 800 EUR
# Detalhes- 1 , 2 , Area total 158 , Area util None
# None ,  Viseu , 94 900 EUR
# Detalhes- 1 , 1 , Area total 85 , Area util None
# None ,  Viseu , 149 900 EUR
# Detalhes- 2 , 3 , Area total 121 , Area util None
# None ,  Figueira da Foz, Tavarede , 65 000 EUR
# Detalhes- 2 , 3 , Area total 120 , Area util None
# None ,  Matosinhos, Sao Mamede de Infesta e Senhora da Hora , 425 000 EUR
# Detalhes- 4 , 5 , Area total 350 , Area util None
# None ,  Funchal (Madeira), Sao Martinho (Madeira), Amparo (Madeira) , 325 000 EUR
# Detalhes- 2 , 3 , Area total 153 , Area util None
# None ,  Portimao (Algarve), Praia da Rocha (Algarve) , 325 000 EUR
# Detalhes- 2 , 3 , Area total 150 , Area util None
# None ,  Seixal, Seixal Arrentela e Aldeia de Paio Pires, Paio Pires , 58 000 EUR
# Detalhes- 1 , 2 , Area total 69 , Area util None
# None ,  Silves (Algarve), Armacao de Pera (Algarve), Quinta dos Arcos (Algarve) , 249 000 EUR
# Detalhes- 2 , 2 , Area total 120 , Area util None
# None ,  Lousa, Lousa e Vilarinho, Lousa , 91 500 EUR
# Detalhes- 3 , 3 , Area total 192 , Area util None
# None ,  Torres Novas, Meia Via , 86 000 EUR
# Detalhes- 2 , 3 , Area total 136 , Area util None
# None ,  Elvas, Assuncao Ajuda Salvador e Santo Ildefonso , 71 000 EUR
# Detalhes- 1 , 2 , Area total 98 , Area util None
# None ,  Marinha Grande, Centro , 137 500 EUR
# Detalhes- 2 , 3 , Area total 165 , Area util None
# None ,  Almeirim, Urb. das Milheiras , 105 000 EUR
# Detalhes- 2 , 3 , Area total 136 , Area util None
# None ,  Ponta Delgada (Acores), Sao Jose (Acores) , 470 000 EUR
# Detalhes- 4 , 6 , Area total 380 , Area util None
# None ,  Nazare, Nazare, Nazare , 57 000 EUR
# Detalhes- 1 , 1 , Area total 36 , Area util None
# None ,  Braga, Braga (Maximinos Se e Cividade) , 55 000 EUR
# Detalhes- 1 , 2 , Area total 68 , Area util None
# None ,  Soure , 30 500 EUR
# Detalhes- 1 , 3 , Area total 68 , Area util None
# None ,  Albufeira (Algarve), Albufeira e Olhos de Agua (Algarve), A. S. Joao (Algarve) , 175 000 EUR
# Detalhes- 1 , 1 , Area total 87 , Area util None
# None ,  Leiria, Coimbrao, Praia do Pedrogao  , 86 150 EUR
# Detalhes- 2 , 3 , Area total 116 , Area util None
# None ,  Loures, Moscavide e Portela, Portela (Portela) , 330 000 EUR
# Detalhes- 2 , 4 , Area total 169 , Area util None
# None ,  Albufeira (Algarve), Albufeira e Olhos de Agua (Algarve), Torre da Medronheira (Olhos de Agua) (Algarve) , 200 000 EUR
# Detalhes- 2 , 2 , Area total 120 , Area util None
# None ,  Cartaxo, Cartaxo e Vale da Pinta , 85 000 EUR
# Detalhes- 1 , 2 , Area total 110 , Area util None
# None ,  Santarem, Marvila Ribeira Santarem S.Salvador S.Nicolau, Zona Historica (Marvila) , 185 000 EUR
# Detalhes- 3 , 3 , Area total 141 , Area util None
# None ,  Calheta (Madeira) , 135 000 EUR
# Detalhes- 2 , 3 , Area total 172 , Area util None
# None ,  Loule (Algarve), Quarteira (Algarve), Vilamoura (Algarve) , 200 000 EUR
# Detalhes- 1 , 1 , Area total 60 , Area util None
# None ,  Viseu, Orgens , 145 000 EUR
# Detalhes- 3 , 3 , Area total 224 , Area util None
# None ,  Viseu , 250 000 EUR
# Detalhes- 4 , 5 , Area total 300 , Area util None
# None ,  Leiria, Coimbrao, Praia do Pedrogao  , 68 000 EUR
# Detalhes- 2 , 3 , Area total 119 , Area util None
# None ,  Nazare, Nazare, Nazare , 499 000 EUR
# Detalhes- 3 , 3 , Area total 320 , Area util None
# None ,  Coimbra, Sao Martinho do Bispo e Ribeira de Frades, Fala , 90 000 EUR
# Detalhes- 2 , 3 , Area total 137 , Area util None
# None ,  Viseu, Repeses e Sao Salvador , 105 000 EUR
# Detalhes- 1 , 2 , Area total 133 , Area util None
# None ,  Pombal , 62 500 EUR
# Detalhes- 1 , 2 , Area total 89 , Area util None
# None ,  Silves (Algarve), Alcantarilha e Pera (Algarve), Centro (Algarve) , 100 000 EUR
# Detalhes- 2 , 3 , Area total 141 , Area util None
# None ,  Nazare, Nazare, Nazare , 125 000 EUR
# Detalhes- 1 , 2 , Area total 80 , Area util None
# None ,  Viana do Castelo, Santa Maria Maior e Monserrate e Meadela , 95 000 EUR
# Detalhes- 2 , 3 , Area total 117 , Area util None
# None ,  Albufeira (Algarve), Albufeira e Olhos de Agua (Algarve) , 92 000 EUR
# Detalhes- 2 , 1 , Area total 76 , Area util None
# None ,  Elvas, Assuncao Ajuda Salvador e Santo Ildefonso , 70 000 EUR
# Detalhes- 1 , 2 , Area total 396 , Area util None
# None ,  Albufeira (Algarve), Albufeira e Olhos de Agua (Algarve), Baixa de Albufeira (Algarve) , 130 000 EUR
# Detalhes- 1 , 1 , Area total 35 , Area util None
# None ,  Lisboa, Belem, Restelo , 690 000 EUR
# Detalhes- 2 , 2 , Area total 182 , Area util None
# None ,  Silves (Algarve), Armacao de Pera (Algarve) , 185 000 EUR
# Detalhes- 1 , 1 , Area total 55 , Area util None
# None ,  Albufeira (Algarve), Albufeira e Olhos de Agua (Algarve) , 150 000 EUR
# Detalhes- 1 , 1 , Area total 74 , Area util None
# None ,  Porto Santo (Madeira), Centro (Madeira) , 125 000 EUR
# Detalhes- 2 , 2 , Area total 101 , Area util None
# None ,  Coimbra, Santo Antonio dos Olivais, Qta. da Maozinha , 650 000 EUR
# Detalhes- 2 , 4 , Area total 340 , Area util None
# None ,  Lisboa, Belem , 240 000 EUR
# Detalhes- 2 , 4 , Area total 200 , Area util None
# None ,  Lisboa, Sao Domingos de Benfica , 915 000 EUR
# Detalhes- 4 , 3 , Area total 193 , Area util None
# None ,  Vieira do Minho, Rossas , 117 100 EUR
# Detalhes- 3 , 3 , Area total 2 200 , Area util None
# None ,  Chamusca, Chamusca e Pinheiro Grande , 210 000 EUR
# Detalhes- 0 , 0 , Area total 808 , Area util None
# None ,  Terras de Bouro, Valdosende, Geres , 975 000 EUR
# Detalhes- 3 , 4 , Area total 23 646 , Area util None
# None ,  Porto de Mos, Mira de Aire, Centro , 140 000 EUR
# Detalhes- 3 , 3 , Area total 216 , Area util None
# None ,  Almada, Charneca de Caparica e Sobreda, Quintinhas , 290 000 EUR
# Detalhes- 2 , 3 , Area total 300 , Area util None
# None ,  Alcochete, Sao Francisco, Cercal de Cima , 340 000 EUR
# Detalhes- 5 , 3 , Area total 248 , Area util None
# None ,  Vidigueira , 126 000 EUR
# Detalhes- 3 , 3 , Area total 129 , Area util None
# None ,  Braga, Lomar e Arcos , 220 000 EUR
# Detalhes- 4 , 4 , Area total 2 448 , Area util None
# None ,  Valongo , 399 000 EUR
# Detalhes- 7 , 5 , Area total 427 , Area util None
# None ,  Cascais, Carcavelos e Parede, Arneiro , 815 000 EUR
# Detalhes- 5 , 4 , Area total 320 , Area util None
# None ,  Resende, Anreade e Sao Romao de Aregos , 2 500 000 EUR
# Detalhes- 8 , 13 , Area total 23 570 , Area util None
# None ,  Montijo, Montijo e Afonsoeiro, Montijo , 175 000 EUR
# Detalhes- 1 , 2 , Area total 100 , Area util None
# None ,  Almada, Charneca de Caparica e Sobreda , 285 000 EUR
# Detalhes- 3 , 3 , Area total 160 , Area util None
# None ,  Barcelos, Gilmonde , 159 000 EUR
# Detalhes- 3 , 6 , Area total 1 000 , Area util None
# None ,  Castelo Branco, Se , 130 000 EUR
# Detalhes- 2 , 6 , Area total 220 , Area util None
# None ,  Braga, Priscos , 224 000 EUR
# Detalhes- 1 , 3 , Area total 334 , Area util None
# None ,  Valongo, Ermesinde , 400 000 EUR
# Detalhes- 3 , 3 , Area total 773 , Area util None
# None ,  Mora, Brotas , 88 000 EUR
# Detalhes- 1 , 3 , Area total 247 , Area util None
# None ,  Alpiarca, Centro , 100 000 EUR
# Detalhes- 2 , 3 , Area total 126 , Area util None
# None ,  Alcanena, Alcanena e Vila Moreira , 42 000 EUR
# Detalhes- 1 , 2 , Area total 138 , Area util None
# None ,  Lagoa (Algarve), Estombar e Parchal (Algarve), Bela Vista (Parchal) (Algarve) , 975 000 EUR
# Detalhes- 4 , 3 , Area total 600 , Area util None
# None ,  Oliveira de Azemeis, Fajoes , 180 000 EUR
# Detalhes- 2 , 3 , Area total 231 , Area util None
# None ,  Albufeira (Algarve), Albufeira e Olhos de Agua (Algarve), Mouraria (Albufeira) (Algarve) , 1 250 000 EUR
# Detalhes- 4 , 3 , Area total 6 260 , Area util None
# None ,  Ferreira do Alentejo, Ferreira do Alentejo e Canhestros , 73 500 EUR
# Detalhes- 1 , 2 , Area total 87 , Area util None
# None ,  Ferreira do Alentejo, Figueira dos Cavaleiros , 184 000 EUR
# Detalhes- 2 , 7 , Area total 421 , Area util None
# None ,  Cascais, Cascais e Estoril, Sao Pedro do Estoril , 845 000 EUR
# Detalhes- 3 , 4 , Area total 267 , Area util None
# None ,  Silves (Algarve), Sao Bartolomeu de Messines (Algarve), Ribeira de Arade (Algarve) , 135 000 EUR
# Detalhes- 1 , 4 , Area total 4 880 , Area util None
# None ,  Lagoa (Algarve), Estombar e Parchal (Algarve), Bela Vista (Parchal) (Algarve) , 650 000 EUR
# Detalhes- 4 , 4 , Area total 660 , Area util None
# None ,  Vila Vicosa, Nossa Senhora da Conceicao e Sao Bartolomeu , 109 000 EUR
# Detalhes- 5 , 9 , Area total 330 , Area util None
# None ,  Trofa, Bougado (Sao Martinho e Santiago), Centro (Sao Martinho (Bougado)) , 350 000 EUR
# Detalhes- 0 , 0 , Area total 2 262 , Area util None
# None ,  Penafiel, Lagares e Figueira, Lagares , 62 000 EUR
# Detalhes- 1 , 2 , Area total 571 , Area util None
# None ,  Tabua, Pinheiro de Coja e Meda de Mouros , 110 000 EUR
# Detalhes- 2 , 5 , Area total 421 , Area util None
# None ,  Sesimbra, Sesimbra (Castelo), Santana , 1 300 000 EUR
# Detalhes- 4 , 5 , Area total 1 984 , Area util None
# None ,  Almada, Costa da Caparica, Costa de Caparica , 920 000 EUR
# Detalhes- 5 , 11 , Area total 385 , Area util None
# None ,  Funchal (Madeira), Santo Antonio (Madeira), Courelas (Madeira) , 114 400 EUR
# Detalhes- 1 , 1 , Area total 212 , Area util None
# None ,  Alcobaca, Pataias e Martinganca , 132 500 EUR
# Detalhes- 3 , 3 , Area total 157 , Area util None
# None ,  Santarem, Achete Azoia de Baixo e Povoa de Santarem , 195 000 EUR
# Detalhes- 3 , 4 , Area total 235 , Area util None
# None ,  Albufeira (Algarve), Paderne (Algarve), Casas (Algarve) , 240 000 EUR
# Detalhes- 2 , 4 , Area total 1 600 , Area util None
# None ,  Albufeira (Algarve), Albufeira e Olhos de Agua (Algarve), Areias de Sao Joao (Albufeira) (Algarve) , 169 000 EUR
# Detalhes- 1 , 1 , Area total 108 , Area util None
# None ,  Sesimbra, Quinta do Conde, Conde Iii , 157 500 EUR
# Detalhes- 2 , 3 , Area total 223 , Area util None
# None ,  Peniche, Atouguia da Baleia, Praia da Consolacao , 495 000 EUR
# Detalhes- 4 , 5 , Area total 200 , Area util None
# None ,  Almada, Charneca de Caparica e Sobreda, Aroeira , 385 000 EUR
# Detalhes- 3 , 3 , Area total 477 , Area util None
# None ,  Braga, Sao Vitor, Feira Nova , 80 000 EUR
# Detalhes- 1 , 3 , Area total 230 , Area util None
# None ,  Silves (Algarve), Sao Bartolomeu de Messines (Algarve) , 169 000 EUR
# Detalhes- 1 , 2 , Area total 76 480 , Area util None
# None ,  Almada, Laranjeiro e Feijo, Feijo  , 150 000 EUR
# Detalhes- 1 , 2 , Area total 92 , Area util None
# None ,  Alcobaca, Alcobaca e Vestiaria , 235 000 EUR
# Detalhes- 2 , 8 , Area total 660 , Area util None
# None ,  Evora, Malagueira e Horta das Figueiras, Vila Academica , 340 000 EUR
# Detalhes- 4 , 3 , Area total 382 , Area util None
# None ,  Evora, Evora (Sao Mamede Se Sao Pedro e Santo Antao) , 135 000 EUR
# Detalhes- 1 , 2 , Area total 103 , Area util None
# None ,  Funchal (Madeira), Sao Roque (Madeira) , 155 000 EUR
# Detalhes- 2 , 2 , Area total 341 , Area util None
# None ,  Viana do Castelo, Geraz do Lima (S.Maria S.Leocadia Moreira) Deao , 120 000 EUR
# Detalhes- 4 , 4 , Area total 1 720 , Area util None
# None ,  Torres Novas, Olaia e Paco , 170 000 EUR
# Detalhes- 3 , 6 , Area total 215 , Area util None
# None ,  Torres Novas, Olaia e Paco , 41 000 EUR
# Detalhes- 1 , 4 , Area total 189 , Area util None
# None ,  Nordeste (Acores), Santana (Acores) , 95 000 EUR
# Detalhes- 1 , 2 , Area total 437 , Area util None
# ...
# Detalhes- 2 , 2 , Area total 120 , Area util None
# None ,  Almada, Charneca de Caparica e Sobreda, Vale Fetal , 107 500 EUR
# Detalhes- 1 , 2 , Area total 85 , Area util None
# None ,  Seixal, Seixal Arrentela e Aldeia de Paio Pires, Paio Pires , 90 150 EUR
# Detalhes- 1 , 2 , Area total 75 , Area util None
# None ,  Lisboa, Parque das Nacoes, Expo Norte , 360 000 EUR
# Detalhes- 1 , 1 , Area total 104 , Area util None
# None ,  Lisboa, Penha de Franca, Alto Sao Joao , 187 000 EUR
# Detalhes- 1 , 1 , Area total 65 , Area util None
# None ,  Evora, Malagueira e Horta das Figueiras, Quinta do Valente , 170 000 EUR
# Detalhes- 1 , 2 , Area total 84 , Area util None
# None ,  Seixal, Seixal Arrentela e Aldeia de Paio Pires, Paio Pires , 89 500 EUR
# Detalhes- 1 , 2 , Area total 102 , Area util None
# None ,  Seixal, Corroios, Sta. Marta do Pinhal , 105 000 EUR
# Detalhes- 1 , 2 , Area total 96 , Area util None
# None ,  Loures, Santa Iria de Azoia Sao Joao da Talha e Bobadela, Vale de Figueira , 258 000 EUR
# Detalhes- 3 , 3 , Area total 113 , Area util None
# None ,  Barreiro, Barreiro e Lavradio, Fidalguinhos (Lavradio) , 135 000 EUR
# Detalhes- 1 , 2 , Area total 110 , Area util None
# None ,  Almada, Charneca de Caparica e Sobreda, Herdade da Aroeira , 430 000 EUR
# Detalhes- 2 , 3 , Area total 125 , Area util None
# None ,  Leiria, Marrazes e Barosa , 76 500 EUR
# Detalhes- 2 , 3 , Area total 107 , Area util None
# None ,  Almada, Laranjeiro e Feijo, Feijo  , 199 500 EUR
# Detalhes- 2 , 4 , Area total 134 , Area util None
# None ,  Albufeira (Algarve), Albufeira e Olhos de Agua (Algarve), Falesia (Albufeira) (Algarve) , 290 000 EUR
# Detalhes- 2 , 2 , Area total 103 , Area util None
# None ,  Portimao (Algarve), Praia da Rocha (Algarve) , 116 000 EUR
# Detalhes- 2 , 2 , Area total 90 , Area util None
# None ,  Braga, Braga (Maximinos Se e Cividade), Estacao (Maximinos) , 175 000 EUR
# Detalhes- 3 , 3 , Area total 184 , Area util None
# None ,  Funchal (Madeira), Sao Martinho (Madeira), Casa Branca (Madeira) , 230 000 EUR
# Detalhes- 2 , 3 , Area total 110 , Area util None
# None ,  Seixal, Amora , 89 150 EUR
# Detalhes- 1 , 2 , Area total 69 , Area util None
# None ,  Viseu, Abraveses , 120 000 EUR
# Detalhes- 2 , 3 , Area total 216 , Area util None
# None ,  Lisboa, Lumiar , 287 000 EUR
# Detalhes- 1 , 1 , Area total 103 , Area util None
# None ,  Marinha Grande, Boavista , 69 500 EUR
# Detalhes- 1 , 2 , Area total 124 , Area util None
# None ,  Viana do Castelo, Darque , 65 000 EUR
# Detalhes- 2 , 3 , Area total 98 , Area util None
# None ,  Santa Cruz (Madeira), Canico (Madeira), Garajau (Madeira) , 120 000 EUR
# Detalhes- 1 , 1 , Area total 102 , Area util None
# None ,  Oeiras, Oeiras e S.Juliao da Barra Paco de Arcos e Caxias, Medrosa , 245 000 EUR
# Detalhes- 1 , 4 , Area total 103 , Area util None
# None ,  Seixal, Corroios , 110 000 EUR
# Detalhes- 1 , 2 , Area total 92 , Area util None
# None ,  Almada, Almada Cova da Piedade Pragal e Cacilhas, Almada , 76 000 EUR
# Detalhes- 1 , 1 , Area total 81 , Area util None
# None ,  Lagoa (Algarve), Porches (Algarve), Quinta do Torrejao (Algarve) , 113 500 EUR
# Detalhes- 1 , 1 , Area total 80 , Area util None
# None ,  Lagoa (Algarve), Porches (Algarve), Na Sr.a da Rocha (Algarve) , 167 500 EUR
# Detalhes- 2 , 1 , Area total 96 , Area util None
# None ,  Seixal, Seixal Arrentela e Aldeia de Paio Pires, Quinta da Trindade , 107 000 EUR
# Detalhes- 1 , 0 , Area total 55 , Area util None
# None ,  Silves (Algarve), Armacao de Pera (Algarve) , 98 500 EUR
# Detalhes- 1 , 0 , Area total 43 , Area util None
# None ,  Sintra, Massama e Monte Abraao, Encosta do Sol , 171 550 EUR
# Detalhes- 2 , 2 , Area total 103 , Area util None
# None ,  Marinha Grande, Casal dos Ossos , 150 000 EUR
# Detalhes- 3 , 3 , Area total 185 , Area util None
# None ,  Barreiro, Barreiro e Lavradio, Fidalguinhos (Lavradio) , 139 000 EUR
# Detalhes- 1 , 2 , Area total 125 , Area util None
# None ,  Oeiras, Alges Linda-A-Velha e Cruz Quebrada-Dafundo, Alges , 435 000 EUR
# Detalhes- 3 , 3 , Area total 170 , Area util None
# None ,  Amadora, Venteira, Bairro de Janeiro , 106 500 EUR
# Detalhes- 2 , 2 , Area total 110 , Area util None
# None ,  Seixal, Corroios, Quinta do Rouxinol , 109 500 EUR
# Detalhes- 1 , 3 , Area total 96 , Area util None
# None ,  Setubal, Setubal (Sao Sebastiao), Bairro da Conceicao , 179 900 EUR
# Detalhes- 2 , 3 , Area total 106 , Area util None
# None ,  Amadora, Falagueira-Venda Nova, Bairro da Cometna , 267 000 EUR
# Detalhes- 2 , 3 , Area total 173 , Area util None
# None ,  Sintra, Algueirao-Mem Martins, Mem Martins , 127 500 EUR
# Detalhes- 1 , 2 , Area total 63 , Area util None
# None ,  Matosinhos, Sao Mamede de Infesta e Senhora da Hora , 105 000 EUR
# Detalhes- 1 , 1 , Area total 77 , Area util None
# None ,  Almada, Almada Cova da Piedade Pragal e Cacilhas, Almada , 110 000 EUR
# Detalhes- 1 , 1 , Area total 65 , Area util None
# None ,  Entroncamento, Sao Joao Baptista , 65 000 EUR
# Detalhes- 1 , 2 , Area total 87 , Area util None
# None ,  Cascais, Sao Domingos de Rana, Alto do Macao , 140 000 EUR
# Detalhes- 1 , 3 , Area total 110 , Area util None
# None ,  Moita, Baixa da Banheira e Vale da Amoreira, Bxa da Banheira-Mercado , 43 500 EUR
# Detalhes- 1 , 2 , Area total 50 , Area util None
# None ,  Faro (Algarve), Faro (Se e Sao Pedro) (Algarve), Bom Joao (Se) (Algarve) , 125 000 EUR
# Detalhes- 1 , 1 , Area total 127 , Area util None
# None ,  Montijo, Montijo e Afonsoeiro , 100 000 EUR
# Detalhes- 1 , 2 , Area total 92 , Area util None
# None ,  Braga, Braga (Maximinos Se e Cividade) , 122 000 EUR
# Detalhes- 4 , 4 , Area total 170 , Area util None
# None ,  Palmela, Quinta do Anjo, Colinas da Arrabida , 118 000 EUR
# Detalhes- 2 , 3 , Area total 117 , Area util None
# None ,  Odivelas , 155 000 EUR
# Detalhes- 1 , 2 , Area total 51 , Area util None
# None ,  Lisboa, Benfica , 150 000 EUR
# Detalhes- 1 , 2 , Area total 72 , Area util None
# None ,  Oeiras, Porto Salvo , 190 000 EUR
# Detalhes- 1 , 1 , Area total 75 , Area util None
# None ,  Almada, Charneca de Caparica e Sobreda, Sobreda , 100 000 EUR
# Detalhes- 1 , 3 , Area total 89 , Area util None
# None ,  Sintra, Massama e Monte Abraao, Queluz , 157 000 EUR
# Detalhes- 1 , 2 , Area total 113 , Area util None
# None ,  Lisboa, Campo de Ourique , 350 000 EUR
# Detalhes- 2 , 2 , Area total 74 , Area util None
# None ,  Palmela, Quinta do Anjo, Palmela Village , 92 000 EUR
# Detalhes- 1 , 1 , Area total 58 , Area util None
# None ,  Seixal, Corroios, Miratejo , 75 000 EUR
# Detalhes- 1 , 2 , Area total 72 , Area util None
# None ,  Montijo, Montijo e Afonsoeiro , 184 000 EUR
# Detalhes- 2 , 3 , Area total 127 , Area util None
# None ,  Barcelos, Barqueiros , 99 500 EUR
# Detalhes- 2 , 3 , Area total 108 , Area util None
# None ,  Loures, Santo Antonio dos Cavaleiros e Frielas, Cidade Nova , 105 000 EUR
# Detalhes- 1 , 2 , Area total 71 , Area util None
# None ,  Vila Nova de Gaia, Canelas, Centro , 105 000 EUR
# Detalhes- 2 , 2 , Area total 105 , Area util None
# None ,  Portimao (Algarve), Boavista (Algarve) , 115 000 EUR
# Detalhes- 2 , 3 , Area total 123 , Area util None
# None ,  Amadora, Mina de Agua, Estacao (Mina) , 135 000 EUR
# Detalhes- 1 , 1 , Area total 100 , Area util None
# None ,  Arraiolos , 35 000 EUR
# Detalhes- 1 , 1 , Area total 69 , Area util None
# None ,  Lisboa, Sao Vicente, Alfama , 170 000 EUR
# Detalhes- 2 , 0 , Area total 53 , Area util None
# None ,  Lisboa, Sao Vicente, Alfama , 168 000 EUR
# Detalhes- 1 , 2 , Area total 38 , Area util None
# None ,  Viana do Alentejo , 50 000 EUR
# Detalhes- 1 , 1 , Area total 146 , Area util None
# None ,  Almada, Laranjeiro e Feijo, Feijo  , 124 000 EUR
# Detalhes- 1 , 3 , Area total 95 , Area util None
# None ,  Portimao (Algarve), Praia dos 3 Castelos (Algarve) , 310 000 EUR
# Detalhes- 2 , 2 , Area total 116 , Area util None
# None ,  Portimao (Algarve), Praia da Rocha (Algarve) , 360 000 EUR
# Detalhes- 2 , 2 , Area total 116 , Area util None
# None ,  Seixal, Amora , 80 000 EUR
# Detalhes- 1 , 3 , Area total 83 , Area util None
# None ,  Amadora, Venteira, Bingo , 76 250 EUR
# Detalhes- 1 , 1 , Area total 37 , Area util None
# None ,  Portimao (Algarve), Praia dos 3 Castelos (Algarve) , 225 000 EUR
# Detalhes- 1 , 1 , Area total 86 , Area util None
# None ,  Portimao (Algarve), Praia dos 3 Castelos (Algarve) , 225 000 EUR
# Detalhes- 1 , 1 , Area total 86 , Area util None
# None ,  Portimao (Algarve), Praia dos 3 Castelos (Algarve) , 480 000 EUR
# Detalhes- 3 , 3 , Area total 164 , Area util None
# None ,  Odivelas , 165 000 EUR
# Detalhes- 1 , 2 , Area total 128 , Area util None
# None ,  Portimao (Algarve), 3 Bicos (Algarve) , 109 500 EUR
# Detalhes- 1 , 2 , Area total 81 , Area util None
# None ,  Lisboa, Olivais, Olivais Sul , 215 000 EUR
# Detalhes- 1 , 4 , Area total 95 , Area util None
# None ,  Cascais, Alcabideche, Amoreira , 140 000 EUR
# Detalhes- 1 , 2 , Area total 100 , Area util None
# None ,  Figueira da Foz, Buarcos, Sotto Mayor (Buarcos) , 77 500 EUR
# Detalhes- 2 , 3 , Area total 113 , Area util None
# None ,  Sintra, S.Maria e S.Miguel S.Martinho S.Pedro Penaferrim, Portela de Sintra , 130 000 EUR
# Detalhes- 1 , 2 , Area total 70 , Area util None
# None ,  Lisboa, Misericordia, Cais do Sodre , 485 000 EUR
# Detalhes- 1 , 2 , Area total 61 , Area util None
# None ,  Chaves, Santa Maria Maior , 115 000 EUR
# Detalhes- 2 , 3 , Area total 124 , Area util None
# None ,  Amadora, Mina de Agua, Casal de Sao Bras (Sao Bras) , 140 000 EUR
# Detalhes- 1 , 2 , Area total 76 , Area util None
# None ,  Nazare, Nazare , 120 000 EUR
# Detalhes- 1 , 2 , Area total 150 , Area util None
# None ,  Lisboa, Sao Domingos de Benfica, Califa , 187 500 EUR
# Detalhes- 1 , 1 , Area total 61 , Area util None
# None ,  Cascais, Cascais e Estoril, Costa da Guia (Cascais) , 310 000 EUR
# Detalhes- 2 , 2 , Area total 100 , Area util None
# None ,  Sintra, Queluz e Belas, Belas , 98 500 EUR
# Detalhes- 1 , 2 , Area total 74 , Area util None
# None ,  Seixal, Amora, Fogueteiro , 68 500 EUR
# Detalhes- 1 , 3 , Area total 91 , Area util None
# None ,  Faro (Algarve), Montenegro (Algarve) , 165 000 EUR
# Detalhes- 2 , 3 , Area total 129 , Area util None
# None ,  Setubal, S.Juliao N.Sao da Anunciada e S.Maria da Graca, Ciprestes , 137 500 EUR
# Detalhes- 2 , 3 , Area total 127 , Area util None
# None ,  Montijo, Montijo e Afonsoeiro, Saldanha (Montijo) , 310 000 EUR
# Detalhes- 3 , 5 , Area total 319 , Area util None
# None ,  Nazare, Nazare, Camarcao , 132 500 EUR
# Detalhes- 2 , 3 , Area total 248 , Area util None
# None ,  Almada, Almada Cova da Piedade Pragal e Cacilhas, Cova da Piedade , 99 000 EUR
# Detalhes- 1 , 2 , Area total 60 , Area util None
# None ,  Sesimbra, Sesimbra (Castelo), Aldeia do Meco , 150 000 EUR
# Detalhes- 1 , 1 , Area total 76 , Area util None
# None ,  Braga, Braga (Maximinos Se e Cividade) , 120 000 EUR
# Detalhes- 2 , 2 , Area total 95 , Area util None
# None ,  Caldas da Rainha, Nossa Senhora do Populo Coto e Sao Gregorio , 210 000 EUR
# Detalhes- 2 , 3 , Area total 100 , Area util None
# None ,  Caldas da Rainha, Nossa Senhora do Populo Coto e Sao Gregorio , 250 000 EUR
# Detalhes- 2 , 4 , Area total 120 , Area util None
# None ,  Lagos (Algarve), Sao Goncalo , 250 000 EUR
# Detalhes- 2 , 3 , Area total 130 , Area util None
# None ,  Almada, Almada Cova da Piedade Pragal e Cacilhas, Pragal (Almada) , 76 500 EUR
# Detalhes- 1 , 3 , Area total 86 , Area util None
# None ,  Maia, Pedroucos , 95 000 EUR
# Detalhes- 2 , 3 , Area total 99 , Area util None
# None ,  Lagoa (Algarve), Porches (Algarve), Alporchinhos (Algarve) , 270 000 EUR
# Detalhes- 2 , 1 , Area total 145 , Area util None
# None ,  Almada, Almada Cova da Piedade Pragal e Cacilhas, Cova da Piedade , 99 900 EUR
# Detalhes- 1 , 2 , Area total 66 , Area util None
# None ,  Montijo, Montijo e Afonsoeiro, Montijo , 165 000 EUR
# Detalhes- 2 , 3 , Area total 145 , Area util None
# None ,  Sintra, Rio de Mouro, Paioes (Rio de Mouro) , 154 000 EUR
# Detalhes- 1 , 2 , Area total 120 , Area util None
# None ,  Seixal, Seixal Arrentela e Aldeia de Paio Pires, Fogueteiro (Seixal) , 82 000 EUR
# Detalhes- 1 , 2 , Area total 71 , Area util None
# None ,  Lisboa, Arroios , 320 000 EUR
# Detalhes- 1 , 1 , Area total 96 , Area util None
# None ,  Portimao (Algarve), Vale de Lagar (Algarve) , 140 000 EUR
# Detalhes- 2 , 3 , Area total 125 , Area util None
# None ,  Povoa de Lanhoso, Fonte Arcada e Oliveira , 90 000 EUR
# Detalhes- 1 , 2 , Area total 114 , Area util None
# None ,  Sintra, Cacem e Sao Marcos, Sao Marcos , 148 800 EUR
# Detalhes- 1 , 2 , Area total 82 , Area util None
# None ,  Vila Franca de Xira, Vialonga , 88 000 EUR
# Detalhes- 1 , 2 , Area total 70 , Area util None
# None ,  Lisboa, Campo de Ourique, Campo de Ourique (Santa Isabel) , 420 000 EUR
# Detalhes- 2 , 4 , Area total 94 , Area util None
# None ,  Matosinhos, Custoias Leca do Balio e Guifoes , 190 000 EUR
# Detalhes- 2 , 3 , Area total 125 , Area util None
# None ,  Oeiras, Oeiras e S.Juliao da Barra Paco de Arcos e Caxias, Parque dos Poetas , 540 000 EUR
# Detalhes- 2 , 4 , Area total 164 , Area util None
# None ,  Odivelas, Colinas do Cruzeiro , 267 500 EUR
# Detalhes- 2 , 2 , Area total 136 , Area util None
# None ,  Povoa de Varzim, Aver-O-Mar Amorim e Terroso , 170 000 EUR
# Detalhes- 2 , 3 , Area total 143 , Area util None
# None ,  Almada, Laranjeiro e Feijo, Laranjeiro , 90 000 EUR
# Detalhes- 1 , 1 , Area total 50 , Area util None
# None ,  Paredes, Casteloes de Cepeda , 132 000 EUR
# Detalhes- 2 , 2 , Area total 124 , Area util None
# None ,  Cascais, Cascais e Estoril, Guia , 540 000 EUR
# Detalhes- 2 , 2 , Area total 110 , Area util None
# None ,  Seixal, Corroios, Miratejo , 85 000 EUR
# Detalhes- 2 , 2 , Area total 79 , Area util None
# None ,  Almada, Almada Cova da Piedade Pragal e Cacilhas, Cacilhas , 160 000 EUR
# Detalhes- 2 , 4 , Area total 153 , Area util None
# None ,  Seixal, Seixal Arrentela e Aldeia de Paio Pires, Torre da Marinha , 76 500 EUR
# Detalhes- 1 , 2 , Area total 74 , Area util None
# None ,  Lisboa, Campolide , 200 000 EUR
# Detalhes- 1 , 2 , Area total 77 , Area util None
# None ,  Amadora, Falagueira-Venda Nova , 213 000 EUR
# Detalhes- 2 , 3 , Area total 96 , Area util None
# None ,  Lisboa, Arroios , 398 000 EUR
# Detalhes- 1 , 3 , Area total 100 , Area util None
# None ,  Aljezur (Algarve), Bordeira (Algarve) , 91 000 EUR
# Detalhes- 1 , 0 , Area total 42 , Area util None
# None ,  Cascais, Sao Domingos de Rana, Outeiro de Polima , 290 000 EUR
# Detalhes- 1 , 2 , Area total 91 , Area util None
# None ,  Almada, Charneca de Caparica e Sobreda, Quinta da Caneira , 82 000 EUR
# Detalhes- 1 , 1 , Area total 65 , Area util None
# None ,  Tavira (Algarve), Tavira (Santa Maria e Santiago) (Algarve), Tavira (Algarve) , 125 000 EUR
# Detalhes- 1 , 2 , Area total 82 , Area util None
# None ,  Viseu, Repeses e Sao Salvador , 145 000 EUR
# Detalhes- 3 , 5 , Area total 167 , Area util None
# None ,  Lisboa, Marvila, Braco de Prata , 270 000 EUR
# Detalhes- 1 , 2 , Area total 80 , Area util None
# None ,  Cascais, Cascais e Estoril, Monte Estoril , 320 000 EUR
# Detalhes- 2 , 2 , Area total 128 , Area util None
# None ,  Silves (Algarve), Armacao de Pera (Algarve), Panasqueira (Algarve) , 255 000 EUR
# Detalhes- 2 , 2 , Area total 134 , Area util None
# None ,  Seixal, Seixal Arrentela e Aldeia de Paio Pires, Alto dos Bonecos , 87 000 EUR
# Detalhes- 1 , 2 , Area total 72 , Area util None
# None ,  Odivelas, Urbanizacao Quinta Nova , 280 000 EUR
# Detalhes- 2 , 3 , Area total 142 , Area util None
# None ,  Lisboa, Sao Domingos de Benfica, Praca de Espanha , 300 000 EUR
# Detalhes- 1 , 2 , Area total 75 , Area util None
# None ,  Viseu, Abraveses , 285 000 EUR
# Detalhes- 3 , 3 , Area total 308 , Area util None
# None ,  Viseu, Abraveses , 235 000 EUR
# Detalhes- 2 , 2 , Area total 189 , Area util None
# None ,  Albufeira (Algarve), Albufeira e Olhos de Agua (Algarve), Brejos (Albufeira) (Algarve) , 164 000 EUR
# Detalhes- 1 , 2 , Area total 93 , Area util None
# None ,  Lisboa, Santa Maria Maior , 490 000 EUR
# Detalhes- 1 , 1 , Area total 58 , Area util None
# None ,  Lisboa, Santa Maria Maior , 830 000 EUR
# Detalhes- 1 , 2 , Area total 98 , Area util None
# None ,  Oeiras, Alges Linda-A-Velha e Cruz Quebrada-Dafundo, Alges , 340 000 EUR
# Detalhes- 2 , 3 , Area total 105 , Area util None

# %% [markdown]
# Price By location

# %%
import matplotlib.pyplot as plt

CostByPlace = {}
NumByPlace = {}
CostByPlace["Medio"] = 0
NumByPlace["Medio"] = 0
for house in houses:
    locationaux= house.get("location").split(",")
    location=locationaux[1]
    if location in CostByPlace.keys():
        priceaux = house.get("price").split()
        price=int(priceaux[0]+priceaux[1])
        oldPrice = CostByPlace.get(location)
        CostByPlace[location] = oldPrice+price
        NumByPlace[location]= NumByPlace[location]+1
        CostByPlace["Medio"] = CostByPlace["Medio"] + price
        NumByPlace["Medio"] = NumByPlace["Medio"] +1
    else:
        NumByPlace[location]= 1
        NumByPlace["Medio"] = NumByPlace["Medio"] +1
        priceaux = house.get("price").split()
        price = int(priceaux[0] + priceaux[1])
        CostByPlace[location] = price
        CostByPlace["Medio"] = CostByPlace["Medio"] + price

for key in CostByPlace.keys():
    CostByPlace[key]= CostByPlace[key]/ NumByPlace[key]


CostByPlace = {k: v for k, v in sorted(CostByPlace.items(), key=lambda item: item[1])}
print(CostByPlace)
print( list(reversed(list(CostByPlace.keys())))[0:3])

plt.bar(range(5),  list(reversed(list(CostByPlace.values())))[0:5], align='center')
plt.xticks(range(5), list(reversed(list(CostByPlace.keys())))[0:5])
plt.show()

# %% [markdown]
# Square Feet by location

# %%
import matplotlib.pyplot as plt

AreaByPlace = {}
NumOfArea = {}
AreaByPlace["Medio"] = 0
NumOfArea["Medio"] = 0
for house in houses:
    locationaux= house.get("location").split(",")
    location=locationaux[1]
    if location in AreaByPlace.keys():
      #fix if area >= 1 000 cause space gets added
        priceaux2 = house.get("gross_area")
        if len(house.get("gross_area")) > 3:
          priceaux = house.get("gross_area").split()
          priceaux2 = priceaux[0] + priceaux[1]
        price = int(priceaux2)
        oldPrice = AreaByPlace.get(location)
        AreaByPlace[location] = oldPrice+price
        NumOfArea[location]= NumOfArea[location]+1
        AreaByPlace["Medio"] = AreaByPlace["Medio"] + price
        NumOfArea["Medio"] = NumOfArea["Medio"] +1
    else:
        NumOfArea[location]= 1
        NumOfArea["Medio"] = NumOfArea["Medio"] +1
        priceaux2 = house.get("gross_area")
        if len(house.get("gross_area")) > 3:
          priceaux = house.get("gross_area").split()
          priceaux2 = priceaux[0] + priceaux[1]
        price = int(priceaux2)
        AreaByPlace[location] = price
        AreaByPlace["Medio"] = AreaByPlace["Medio"] + price


for key in AreaByPlace.keys():
    AreaByPlace[key]= AreaByPlace[key]/ NumOfArea[key]


AreaByPlace = {k: v for k, v in sorted(AreaByPlace.items(), key=lambda item: item[1])}
print(AreaByPlace)
print( list(reversed(list(AreaByPlace.keys())))[0:3])

plt.bar(range(5),  list(reversed(list(AreaByPlace.values())))[0:5], align='center')
plt.xticks(range(5), list(reversed(list(AreaByPlace.keys())))[0:5])
plt.show()
# Out:
# {'Medio': 31847875, ' Setubal': 3609629, ' Coimbra': 1301161, ' Vila Real': 380909, ' Lisboa': 1786040, ' Viseu': 716239, ' Santarem': 1964520, ' Guarda': 332771, ' Porto': 1126001, ' Ilha da Madeira (Madeira)': 192309, ' Faro (Algarve)': 8763034, ' Evora': 3842322, ' Portalegre': 463414, ' Braga': 1563478, ' Aveiro': 395576, ' Leiria': 1141860, ' Ilha de Sao Miguel (Acores)': 1257228, ' Viana do Castelo': 887671, ' Braganca': 23357, ' Castelo Branco': 69115, ' Ilha de Santa Maria (Acores)': 844, ' Beja': 2006392, ' Ilha do Faial (Acores)': 2525, ' Ilha da Graciosa (Acores)': 80, ' Ilha de Porto Santo (Madeira)': 20354, ' Ilha do Pico (Acores)': 934, ' Ilha Terceira (Acores)': 112}

# %% [markdown]
# Price By square foot by Location

# %%
import matplotlib.pyplot as plt

CostbySquareMeter = {}
NumOfPlace = {}
CostbySquareMeter["Medio"] = 0
NumOfPlace["Medio"] = 0
for house in houses:
    locationaux= house.get("location").split(",")
    location=locationaux[1]
    if location in CostbySquareMeter.keys():
        priceaux2 = house.get("gross_area")
        if len(house.get("gross_area")) > 3:
          priceaux = house.get("gross_area").split()
          priceaux2 = priceaux[0] + priceaux[1]
        grossArea = int(priceaux2)
        priceaux = house.get("price").split()
        price=int(priceaux[0]+priceaux[1])/grossArea
        #print ( location , grossArea , price , price/grossArea)
        oldPrice = CostbySquareMeter.get(location)
        CostbySquareMeter[location] = oldPrice+price
        NumOfPlace[location]= NumOfPlace[location]+1
        CostbySquareMeter["Medio"] = CostbySquareMeter["Medio"] + price
        NumOfPlace["Medio"] = NumOfPlace["Medio"] +1
    else:
        NumOfPlace[location]= 1
        priceaux2 = house.get("gross_area")
        if len(house.get("gross_area")) > 3:
          priceaux = house.get("gross_area").split()
          priceaux2 = priceaux[0] + priceaux[1]
        grossArea = int(priceaux2)
        NumOfPlace["Medio"] = NumOfPlace["Medio"] +1
        priceaux = house.get("price").split()
        price = int(priceaux[0] + priceaux[1])/grossArea
        CostbySquareMeter[location] = price
        CostbySquareMeter["Medio"] = CostbySquareMeter["Medio"] + price


print(CostbySquareMeter)
for key in CostbySquareMeter.keys():
    CostbySquareMeter[key]= CostbySquareMeter[key]/ NumOfPlace[key]

CostbySquareMeter = {k: v for k, v in sorted(CostbySquareMeter.items(), key=lambda item: item[1])}
print(CostbySquareMeter)
print( list(reversed(list(CostbySquareMeter.keys())))[0:3])

plt.bar(range(5),  list(reversed(list(CostbySquareMeter.values())))[0:5], align='center')
plt.xticks(range(5), list(reversed(list(CostbySquareMeter.keys())))[0:5])
plt.show()
# Out:
# {'Medio': 10830315.980279746, ' Setubal': 1679589.9482899075, ' Coimbra': 234774.99258710913, ' Vila Real': 52361.172481973445, ' Lisboa': 4801238.487713263, ' Viseu': 88275.12737907488, ' Santarem': 132606.562374962, ' Guarda': 6533.03030767222, ' Porto': 1227048.5118189878, ' Ilha da Madeira (Madeira)': 198730.9347050301, ' Faro (Algarve)': 1406751.6038566679, ' Evora': 141296.31186790403, ' Portalegre': 45052.620597803296, ' Braga': 168688.8061961569, ' Aveiro': 84541.24663035909, ' Leiria': 329759.6427172479, ' Ilha de Sao Miguel (Acores)': 133867.5344957496, ' Viana do Castelo': 63708.11010604384, ' Braganca': 3444.0938947789386, ' Castelo Branco': 5686.079906206691, ' Ilha de Santa Maria (Acores)': 426.60586835844566, ' Beja': 19424.492265185956, ' Ilha do Faial (Acores)': 39.00990099009901, ' Ilha da Graciosa (Acores)': 2062.5, ' Ilha de Porto Santo (Madeira)': 3037.3398796173824, ' Ilha do Pico (Acores)': 299.78586723768734, ' Ilha Terceira (Acores)': 1071.4285714285713}
# {'Medio': 1083.0315980279745, ' Setubal': 942.0022144082487, ' Coimbra': 478.1568077130532, ' Vila Real': 399.7036067326217, ' Lisboa': 2101.1984628942073, ' Viseu': 469.5485498886962, ' Santarem': 322.64370407533335, ' Guarda': 343.84370040380105, ' Porto': 1258.5112941733207, ' Ilha da Madeira (Madeira)': 838.5271506541354, ' Faro (Algarve)': 1101.606580937093, ' Evora': 543.4473533380924, ' Portalegre': 402.25554105181516, ' Braga': 359.67762515172046, ' Aveiro': 442.6243279076392, ' Leiria': 528.4609658930254, ' Ilha de Sao Miguel (Acores)': 509.0020323032304, ' Viana do Castelo': 318.5405505302192, ' Braganca': 492.0134135398484, ' Castelo Branco': 473.8399921838909, ' Ilha de Santa Maria (Acores)': 213.30293417922283, ' Beja': 388.4898453037191, ' Ilha do Faial (Acores)': 39.00990099009901, ' Ilha da Graciosa (Acores)': 2062.5, ' Ilha de Porto Santo (Madeira)': 337.48220884637584, ' Ilha do Pico (Acores)': 299.78586723768734, ' Ilha Terceira (Acores)': 1071.4285714285713}

# %% [markdown]
# Price By gross area

# %%
import matplotlib.pyplot as plt

GrossArea=[]
Price=[]
colors=[]
area=[]
for house in houses:
    priceaux2 = house.get("gross_area")
    if len(house.get("gross_area")) > 3:
      priceaux = house.get("gross_area").split()
      priceaux2 = priceaux[0] + priceaux[1]
    grossArea = int(priceaux2)
    GrossArea.append(grossArea)
    priceaux = house.get("price").split()
    price = int(priceaux[0] + priceaux[1])
    Price.append(price)
    colors.append(0.75)
    area.append(50)




plt.scatter(Price, GrossArea, s=area, c=colors, alpha=0.5)
plt.show()
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 59

# %% [markdown]
# Experiences with ipyleaflet

# %%
# !pip install ipyleaflet
# Out:
# Requirement already satisfied: ipyleaflet in /usr/local/lib/python3.6/dist-packages (0.12.3)
# Requirement already satisfied: branca<0.4,>=0.3.1 in /usr/local/lib/python3.6/dist-packages (from ipyleaflet) (0.3.1)
# Requirement already satisfied: traittypes<3,>=0.2.1 in /usr/local/lib/python3.6/dist-packages (from ipyleaflet) (0.2.1)
# Requirement already satisfied: xarray>=0.10 in /usr/local/lib/python3.6/dist-packages (from ipyleaflet) (0.15.1)
# Requirement already satisfied: ipywidgets<8,>=7.5.0 in /usr/local/lib/python3.6/dist-packages (from ipyleaflet) (7.5.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.6/dist-packages (from branca<0.4,>=0.3.1->ipyleaflet) (2.11.1)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from branca<0.4,>=0.3.1->ipyleaflet) (1.12.0)
# Requirement already satisfied: traitlets>=4.2.2 in /usr/local/lib/python3.6/dist-packages (from traittypes<3,>=0.2.1->ipyleaflet) (4.3.3)
# Requirement already satisfied: setuptools>=41.2 in /usr/local/lib/python3.6/dist-packages (from xarray>=0.10->ipyleaflet) (46.1.3)
# Requirement already satisfied: pandas>=0.25 in /usr/local/lib/python3.6/dist-packages (from xarray>=0.10->ipyleaflet) (1.0.3)
# Requirement already satisfied: numpy>=1.15 in /usr/local/lib/python3.6/dist-packages (from xarray>=0.10->ipyleaflet) (1.18.2)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /usr/local/lib/python3.6/dist-packages (from ipywidgets<8,>=7.5.0->ipyleaflet) (3.5.1)
# Requirement already satisfied: ipython>=4.0.0; python_version >= "3.3" in /usr/local/lib/python3.6/dist-packages (from ipywidgets<8,>=7.5.0->ipyleaflet) (5.5.0)
# Requirement already satisfied: nbformat>=4.2.0 in /usr/local/lib/python3.6/dist-packages (from ipywidgets<8,>=7.5.0->ipyleaflet) (5.0.5)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.6/dist-packages (from ipywidgets<8,>=7.5.0->ipyleaflet) (4.6.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.6/dist-packages (from jinja2->branca<0.4,>=0.3.1->ipyleaflet) (1.1.1)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.6/dist-packages (from traitlets>=4.2.2->traittypes<3,>=0.2.1->ipyleaflet) (0.2.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.6/dist-packages (from traitlets>=4.2.2->traittypes<3,>=0.2.1->ipyleaflet) (4.4.2)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.25->xarray>=0.10->ipyleaflet) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.25->xarray>=0.10->ipyleaflet) (2018.9)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.6/dist-packages (from widgetsnbextension~=3.5.0->ipywidgets<8,>=7.5.0->ipyleaflet) (5.2.2)
# Requirement already satisfied: prompt-toolkit<2.0.0,>=1.0.4 in /usr/local/lib/python3.6/dist-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets<8,>=7.5.0->ipyleaflet) (1.0.18)
# Requirement already satisfied: simplegeneric>0.8 in /usr/local/lib/python3.6/dist-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets<8,>=7.5.0->ipyleaflet) (0.8.1)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.6/dist-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets<8,>=7.5.0->ipyleaflet) (0.7.5)
# Requirement already satisfied: pygments in /usr/local/lib/python3.6/dist-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets<8,>=7.5.0->ipyleaflet) (2.1.3)
# Requirement already satisfied: pexpect; sys_platform != "win32" in /usr/local/lib/python3.6/dist-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets<8,>=7.5.0->ipyleaflet) (4.8.0)
# Requirement already satisfied: jupyter-core in /usr/local/lib/python3.6/dist-packages (from nbformat>=4.2.0->ipywidgets<8,>=7.5.0->ipyleaflet) (4.6.3)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /usr/local/lib/python3.6/dist-packages (from nbformat>=4.2.0->ipywidgets<8,>=7.5.0->ipyleaflet) (2.6.0)
# Requirement already satisfied: tornado>=4.0 in /usr/local/lib/python3.6/dist-packages (from ipykernel>=4.5.1->ipywidgets<8,>=7.5.0->ipyleaflet) (4.5.3)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.6/dist-packages (from ipykernel>=4.5.1->ipywidgets<8,>=7.5.0->ipyleaflet) (5.3.4)
# Requirement already satisfied: terminado>=0.3.3; sys_platform != "win32" in /usr/local/lib/python3.6/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.5.0->ipyleaflet) (0.8.3)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.6/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.5.0->ipyleaflet) (5.6.1)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.6/dist-packages (from prompt-toolkit<2.0.0,>=1.0.4->ipython>=4.0.0; python_version >= "3.3"->ipywidgets<8,>=7.5.0->ipyleaflet) (0.1.9)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.6/dist-packages (from pexpect; sys_platform != "win32"->ipython>=4.0.0; python_version >= "3.3"->ipywidgets<8,>=7.5.0->ipyleaflet) (0.6.0)
# Requirement already satisfied: pyzmq>=13 in /usr/local/lib/python3.6/dist-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets<8,>=7.5.0->ipyleaflet) (17.0.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.6/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.5.0->ipyleaflet) (0.8.4)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.6/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.5.0->ipyleaflet) (0.6.0)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.6/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.5.0->ipyleaflet) (0.3)
# Requirement already satisfied: testpath in /usr/local/lib/python3.6/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.5.0->ipyleaflet) (0.4.4)
# Requirement already satisfied: bleach in /usr/local/lib/python3.6/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.5.0->ipyleaflet) (3.1.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.6/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.5.0->ipyleaflet) (1.4.2)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.6/dist-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.5.0->ipyleaflet) (0.5.1)

# %%
from ipyleaflet import Map, Marker, LayersControl

m = Map(center=(50, 0), zoom=5)

marker1 = Marker(name='marker1', location=(48, -2))
marker2 = Marker(name='marker2', location=(50, 0))
marker3 = Marker(name='marker3', location=(52, 2))
m.add_layer(marker1)
m.add_layer(marker2)
m.add_layer(marker3)

control = LayersControl(position='topright')
m.add_control(control)

m
# Out:
# Map(center=[50, 0], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_text…
